# %% [markdown]
# <a href="https://colab.research.google.com/github/nuryaningsih/CodeCraftedAtTripleTen/blob/main/12_Predicting_Car_Market_Value_Quality%2C_Speed%2C_and_Efficiency_in_Rusty_Bargain's_App_Development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# In the rapidly evolving automotive industry, the demand for a reliable and efficient tool to estimate the market value of used cars has become paramount. Rusty Bargain, a company specializing in the sale of pre-owned vehicles, seeks to address this need through the development of a cutting-edge application. This application aims to empower users by providing immediate insights into the market value of their vehicles, leveraging historical data, technical specifications, model versions, and current market prices. To achieve this, Rusty Bargain intends to explore various machine learning models to identify the one that best balances prediction quality, speed, and training time.
#
# ## Objective
# The primary goal of this project is to develop a predictive model that accurately determines the market value of used cars. This entails:
# 1. Evaluating Prediction Quality: The model must generate precise and reliable market value estimates for a wide range of vehicles based on their historical data, technical specifications, and model versions.
# 2. Ensuring Fast Prediction Speed: Given the user-oriented nature of the application, the model must deliver quick predictions to enhance user experience.
# 3. Optimizing Training Time: The model should be relatively fast to train, allowing for periodic retraining as new data becomes available or market conditions change.
#
# ## Stages
# 1. Data Preparation and Exploration
#   * Collect and Observe Data: Gather comprehensive datasets encompassing historical sales, vehicle specifications, model versions, and current market prices.
#   * Data Cleaning: Identify and rectify missing values, outliers, and inconsistencies in the dataset.
#   * Feature Engineering: Develop relevant features that could influence a vehicle's market value, such as age, mileage, make, model, and condition.
# 2. Model Development and Training
#   * Initial Model Selection: Choose a diverse set of machine learning models for initial experimentation, including Decision Trees, Random Forest, Gradient Boosting variants (e.g., XGBoost, LightGBM, CatBoost), and Linear Regression.
#   * Hyperparameter Tuning: Employ techniques like grid search and random search to fine-tune the models' hyperparameters for optimal performance.
#   * Cross-Validation: Utilize k-fold cross-validation to assess the models' performance and ensure they are not overfitting.
# 3. Performance Evaluation
#   * Quality of Prediction: Evaluate the models using metrics such as Mean Absolute Error (MAE), Root Mean Squared Error (RMSE), and R² (Coefficient of Determination) to determine their accuracy and reliability in predicting vehicle market values.
#   * Prediction Speed: Measure the time taken by each model to make predictions, aiming for the fastest possible without compromising quality.
#   * Training Time: Record and compare the time required to train each model, seeking a balance between computational efficiency and predictive performance.
# 4. Conclusion and Model Selection
#   * Based on the analysis of prediction quality, speed, and training time, select the best-performing model(s) for deployment in Rusty Bargain's application.
#   * Discuss the trade-offs between different models and justify the selection of the chosen model.
# 5. Future Directions
#   * Outline potential improvements for the model, such as incorporating more diverse data sources, implementing more advanced feature engineering techniques, or exploring newer machine learning algorithms.
#   * Consider the infrastructure and computational resources needed for deploying the model in a production environment, ensuring it remains scalable and maintainable.
#
# By meticulously following these stages, Rusty Bargain aims to develop a robust application that enhances the car selling and buying process, making it more transparent, efficient, and user-friendly.

# %% [markdown]
# # 1.	Data Preparation and Exploration

# %% [markdown]
# Load the libraries that we think are needed for this project. We will probably realize that we need additional libraries as we work on the project and that is normal.

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.3)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.25.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.0.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
# Import library to process data
import numpy as np
import pandas as pd
import math

# Import Library for viz data
import seaborn as sns
import matplotlib.pyplot as plt

# Import Library for Machine Learning

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
import catboost as cb
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Collect and Observe Data
#
# Load data and perform checks to ensure data is free from problems.

# %%
# Load the data file into a DataFrameLoad the data file into a DataFrame
df = pd.read_csv('/content/drive/MyDrive/DATASET PROJECT/12. Predicting Car Market Value/car_data.csv')

# %%
# Let's see how many rows and columns our dataset has
df.shape
# Out:
# (354369, 16)

# %%
# Display general information/summary about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354369 entries, 0 to 354368
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   DateCrawled        354369 non-null  object
#  1   Price              354369 non-null  int64
#  2   VehicleType        316879 non-null  object
#  3   RegistrationYear   354369 non-null  int64
#  4   Gearbox            334536 non-null  object
#  5   Power              354369 non-null  int64
#  6   Model              334664 non-null  object
#  7   Mileage            354369 non-null  int64
#  8   RegistrationMonth  354369 non-null  int64
#  9   FuelType           321474 non-null  object
#  10  Brand              354369 non-null  object
#  11  NotRepaired        283215 non-null  object
#  12  DateCreated        354369 non-null  object
#  13  NumberOfPictures   354369 non-null  int64
#  14  PostalCode         354369 non-null  int64
#  15  LastSeen           354369 non-null  object
# dtypes: int64(7), object(9)
# memory usage: 43.3+ MB

# %%
# Displays sample data
df.head()
# Out:
#         DateCrawled  Price VehicleType  RegistrationYear Gearbox  Power  \
# 0  24/03/2016 11:52    480         NaN              1993  manual      0
# 1  24/03/2016 10:58  18300       coupe              2011  manual    190
# 2  14/03/2016 12:52   9800         suv              2004    auto    163
# 3  17/03/2016 16:54   1500       small              2001  manual     75
# 4  31/03/2016 17:25   3600       small              2008  manual     69
#
#    Model  Mileage  RegistrationMonth  FuelType       Brand NotRepaired  \
# 0   golf   150000                  0    petrol  volkswagen         NaN
# 1    NaN   125000                  5  gasoline        audi         yes
# 2  grand   125000                  8  gasoline        jeep         NaN
# 3   golf   150000                  6    petrol  volkswagen          no
# 4  fabia    90000                  7  gasoline       skoda          no
#
#         DateCreated  NumberOfPictures  PostalCode          LastSeen
# 0  24/03/2016 00:00                 0       70435  07/04/2016 03:16
# 1  24/03/2016 00:00                 0       66954  07/04/2016 01:46
# 2  14/03/2016 00:00                 0       90480  05/04/2016 12:47
# 3  17/03/2016 00:00                 0       91074  17/03/2016 17:40
# 4  31/03/2016 00:00                 0       60437  06/04/2016 10:17

# %%
# Describe from general information
df.describe()
# Out:
#                Price  RegistrationYear          Power        Mileage  \
# count  354369.000000     354369.000000  354369.000000  354369.000000
# mean     4416.656776       2004.234448     110.094337  128211.172535
# std      4514.158514         90.227958     189.850405   37905.341530
# min         0.000000       1000.000000       0.000000    5000.000000
# 25%      1050.000000       1999.000000      69.000000  125000.000000
# 50%      2700.000000       2003.000000     105.000000  150000.000000
# 75%      6400.000000       2008.000000     143.000000  150000.000000
# max     20000.000000       9999.000000   20000.000000  150000.000000
#
#        RegistrationMonth  NumberOfPictures     PostalCode
# count      354369.000000          354369.0  354369.000000
# mean            5.714645               0.0   50508.689087
# std             3.726421               0.0   25783.096248
# min             0.000000               0.0    1067.000000
# 25%             3.000000               0.0   30165.000000
# 50%             6.000000               0.0   49413.000000
# 75%             9.000000               0.0   71083.000000
# max            12.000000               0.0   99998.000000

# %%
# View data types
df.dtypes
# Out:
# DateCrawled          object
# Price                 int64
# VehicleType          object
# RegistrationYear      int64
# Gearbox              object
# Power                 int64
# Model                object
# Mileage               int64
# RegistrationMonth     int64
# FuelType             object
# Brand                object
# NotRepaired          object
# DateCreated          object
# NumberOfPictures      int64
# PostalCode            int64
# LastSeen             object
# dtype: object

# %%
# Check for missing values
df.isnull().sum().sort_values(ascending=False) / df.shape[0] *100
# Out:
# NotRepaired          20.079070
# VehicleType          10.579368
# FuelType              9.282697
# Gearbox               5.596709
# Model                 5.560588
# DateCrawled           0.000000
# Price                 0.000000
# RegistrationYear      0.000000
# Power                 0.000000
# Mileage               0.000000
# RegistrationMonth     0.000000
# Brand                 0.000000
# DateCreated           0.000000
# NumberOfPictures      0.000000
# PostalCode            0.000000
# LastSeen              0.000000
# dtype: float64

# %%
# Checking for duplication
df.duplicated().sum()
# Out:
# 262

# %% [markdown]
# After loading and inspecting the dataset, several observations can be made:
#
# 1. Missing Values:
#   * There are missing values present in several columns, notably in "NotRepaired," "VehicleType," "FuelType," "Gearbox," and "Model." These missing values range from approximately 5.56% to 20.08% of the total entries.
#   * The presence of missing values can be attributed to various factors such as oversight during data collection, incomplete records, or user omission during data entry.
# 2. Duplicate Entries:
#   * There are 262 duplicated entries within the dataset, suggesting potential data replication during the data collection process or data entry errors.
# 3. Anomalies and Outliers:
#   * Anomalies or outliers were not explicitly identified based on the provided summary statistics. However, certain columns may contain unexpected or unreasonable values that warrant further investigation, such as extremely low or high prices, unrealistic mileage values, or unusual registration years.
#
# To address these observations, several steps can be taken:
#
# 1. Handling Missing Values:
#   * Missing values can be addressed through various techniques, including imputation (replacing missing values with a statistical measure like mean or median), deletion of rows or columns with a significant number of missing values, or using advanced imputation methods such as predictive modeling. The choice of method depends on the specific characteristics of the dataset and the nature of the missing values.
# 2. Dealing with Duplicate Entries:
#   * Duplicate entries should be carefully examined to determine whether they represent genuine duplicates or data entry errors. If they are genuine duplicates, one approach is to retain only the first occurrence of each entry. Alternatively, if duplicate entries indicate data replication issues, further investigation into the data collection process may be necessary to rectify the underlying cause.
# 3. Identifying and Handling Anomalies:
#   * Anomalies or outliers, if present, should be identified and evaluated to determine their impact on the dataset and subsequent analysis. Depending on the context, anomalies may be genuine data points that reflect unusual but valid observations, or they may be errors that need to be corrected or removed. Techniques such as visualization, statistical methods (e.g., z-score or interquartile range), or domain knowledge can be employed to detect and address anomalies appropriately.
#
# The decision-making process for addressing these data quality issues is informed by several factors, including the specific requirements of the predictive modeling task, the extent of missing or duplicate data, and the potential impact of anomalies on model performance. Additionally, considerations such as data integrity, representativeness, and the overall quality of the dataset guide the selection of appropriate data preprocessing strategies.
#
# In summary, thorough data preprocessing, including handling missing values, addressing duplicates, and identifying anomalies, is essential to ensure the integrity and reliability of the dataset for subsequent modeling and analysis tasks. By systematically addressing these data quality issues, we can enhance the robustness and effectiveness of the predictive modeling process for estimating car market values.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Title writing style
#
# Show column headings:

# %%
# list containing the column names in the df table
df.columns
# Out:
# Index(['DateCrawled', 'Price', 'VehicleType', 'RegistrationYear', 'Gearbox',
#        'Power', 'Model', 'Mileage', 'RegistrationMonth', 'FuelType', 'Brand',
#        'NotRepaired', 'DateCreated', 'NumberOfPictures', 'PostalCode',
#        'LastSeen'],
#       dtype='object')

# %%
df = df.rename(columns={'DateCrawled': 'date_crawled',
                        'Price': 'price',
                        'VehicleType': 'vehicle_type',
                        'RegistrationYear': 'registration_year',
                        'Gearbox': 'gearbox',
                        'Power' : 'power',
                        'Model' : 'model',
                        'Mileage' : 'mileage',
                        'RegistrationMonth' : 'registration_month',
                        'FuelType' : 'fuel_type',
                        'Brand' : 'brand',
                        'NotRepaired' : 'not_repaired',
                        'DateCreated' : 'date_created',
                        'NumberOfPictures' : 'number_of_pictures',
                        'PostalCode' : 'postal_code',
                        'LastSeen' : 'last_seen'
                       })

# %%
# check your results: display once again the list containing the column names
df.columns
# Out:
# Index(['date_crawled', 'price', 'vehicle_type', 'registration_year', 'gearbox',
#        'power', 'model', 'mileage', 'registration_month', 'fuel_type', 'brand',
#        'not_repaired', 'date_created', 'number_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# ### Resolve duplicates

# %%
df.duplicated().sum()
# Out:
# 262

# %%
# Cleans duplicate data
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Eliminate unused columns

# %%
df = df.drop(['date_crawled', 'date_created', 'postal_code', 'last_seen'], axis=1)

# %%
df.head()
# Out:
#    price vehicle_type  registration_year gearbox  power  model  mileage  \
# 0    480          NaN               1993  manual      0   golf   150000
# 1  18300        coupe               2011  manual    190    NaN   125000
# 2   9800          suv               2004    auto    163  grand   125000
# 3   1500        small               2001  manual     75   golf   150000
# 4   3600        small               2008  manual     69  fabia    90000
#
#    registration_month fuel_type       brand not_repaired  number_of_pictures
# 0                   0    petrol  volkswagen          NaN                   0
# 1                   5  gasoline        audi          yes                   0
# 2                   8  gasoline        jeep          NaN                   0
# 3                   6    petrol  volkswagen           no                   0
# 4                   7  gasoline       skoda           no                   0

# %% [markdown]
# ### Resolve constant columns

# %%
df['number_of_pictures'].value_counts()
# Out:
# number_of_pictures
# 0    354107
# Name: count, dtype: int64

# %%
df = df.drop(['number_of_pictures'], axis=1)

# %% [markdown]
# ### Deal with strange data

# %%
df['registration_year'].describe()
# Out:
# count    354107.000000
# mean       2004.235355
# std          90.261168
# min        1000.000000
# 25%        1999.000000
# 50%        2003.000000
# 75%        2008.000000
# max        9999.000000
# Name: registration_year, dtype: float64

# %%
df = df[df['registration_year'] < 2024]
df = df[df['registration_year'] > 2000]
df = df[df['power'] != 0].reset_index(drop=True)

# %% [markdown]
# ### Resolve missing values

# %%
# Check for missing values
df.isnull().sum().sort_values(ascending=False) / df.shape[0] *100
# Out:
# not_repaired          13.166096
# vehicle_type           9.393570
# fuel_type              6.312061
# model                  3.435244
# gearbox                1.885779
# price                  0.000000
# registration_year      0.000000
# power                  0.000000
# mileage                0.000000
# registration_month     0.000000
# brand                  0.000000
# dtype: float64

# %%
df = df.fillna('unknown')

# %%
# Check for missing values
df.isnull().sum().sort_values(ascending=False) / df.shape[0] *100
# Out:
# price                 0.0
# vehicle_type          0.0
# registration_year     0.0
# gearbox               0.0
# power                 0.0
# model                 0.0
# mileage               0.0
# registration_month    0.0
# fuel_type             0.0
# brand                 0.0
# not_repaired          0.0
# dtype: float64

# %% [markdown]
# **Data Cleaning**
#
# 1. Renaming Columns
#
# The column names in the dataset were standardized to adhere to a consistent naming convention for better readability and consistency in analysis.
#
# 2. Resolving Duplicates
#
# Initial assessment revealed 262 duplicated rows in the dataset. These duplicates were subsequently removed, ensuring data integrity.
#
# 3. Eliminating Unused Columns
#
# Columns such as 'date_crawled', 'date_created', 'postal_code', and 'last_seen' were deemed unnecessary for the analysis and thus were dropped from the dataset.
#
# 4. Resolving Constant Columns
#
# The column 'number_of_pictures' contained only one unique value (0), indicating that it did not provide any useful information for analysis and was therefore removed.
#
# 5. Dealing with Strange Data
#
# Analysis of the 'registration_year' column revealed anomalies such as years below 1900 and above the current year (2024). These outliers were filtered out to ensure the data remains within a realistic timeframe.
#
# 6. Resolving Missing Values
#
# Several columns contained missing values, with 'not_repaired', 'vehicle_type', 'fuel_type', and 'model' being the most affected. These missing values were imputed with the label 'unknown' to maintain the integrity of the dataset.
#
# **Conclusion**
#
# The data cleaning process involved several steps to ensure the dataset's integrity and quality for subsequent analysis. By standardizing column names, resolving duplicates, eliminating unused columns, addressing strange data, and resolving missing values, the dataset has been prepared for further exploration and modeling.
#
# Insights gained from the cleaning process include:
#   * Identification and removal of duplicate entries to prevent bias in analysis.
#   * Elimination of unnecessary columns to streamline data processing.
#   * Filtering out of outliers in registration years to ensure data consistency.
#   * Imputation of missing values with 'unknown' to maintain dataset completeness.
#
# Overall, the cleaned dataset is now ready for further analysis and modeling to develop a robust predictive model for estimating the market value of used cars.

# %% [markdown]
# ## Feature Engineering

# %%
categorical_features = ['vehicle_type', 'gearbox', 'model', 'fuel_type', 'brand', 'not_repaired']

# %%
for feature in categorical_features:
    print(f'features {feature} {len(df[feature].value_counts())}')
# Out:
# features vehicle_type 9
# features gearbox 3
# features model 246
# features fuel_type 8
# features brand 40
# features not_repaired 3

# %%
df_ohe = df
df_ohe = pd.get_dummies(df_ohe)

# %%
df_ohe.shape
# Out:
# (206652, 314)

# %%
df_ohe.head()
# Out:
#    price  registration_year  power  mileage  registration_month  \
# 0  18300               2011    190   125000                   5
# 1   9800               2004    163   125000                   8
# 2   1500               2001     75   150000                   6
# 3   3600               2008     69    90000                   7
# 4   2200               2004    109   150000                   8
#
#    vehicle_type_bus  vehicle_type_convertible  vehicle_type_coupe  \
# 0             False                     False                True
# 1             False                     False               False
# 2             False                     False               False
# 3             False                     False               False
# 4             False                      True               False
#
#    vehicle_type_other  vehicle_type_sedan  ...  brand_sonstige_autos  \
# 0               False               False  ...                 False
# 1               False               False  ...                 False
# 2               False               False  ...                 False
# 3               False               False  ...                 False
# 4               False               False  ...                 False
#
#    brand_subaru  brand_suzuki  brand_toyota  brand_trabant  brand_volkswagen  \
# 0         False         False         False          False             False
# 1         False         False         False          False             False
# 2         False         False         False          False              True
# 3         False         False         False          False             False
# 4         False         False         False          False             False
#
#    brand_volvo  not_repaired_no  not_repaired_unknown  not_repaired_yes
# 0        False            False                 False              True
# 1        False            False                  True             False
# 2        False             True                 False             False
# 3        False             True                 False             False
# 4        False             True                 False             False
#
# [5 rows x 314 columns]

# %%
# feature selection

df_ohe_train_valid, df_ohe_test = train_test_split(df_ohe, test_size=0.15, random_state=12345)
df_ohe_train, df_ohe_valid = train_test_split(df_ohe_train_valid, test_size=0.25, random_state=12345)

print(df_ohe_train.shape)
print(df_ohe_valid.shape)
print(df_ohe_test.shape)
# Out:
# (131740, 314)
# (43914, 314)
# (30998, 314)

# %% [markdown]
# # Model Development and Training

# %%
def rmse(target, prediction):
    return mean_squared_error(target, prediction)** 0.5

# %%
features_train = df_ohe_train.drop(['price'], axis=1)
target_train = df_ohe_train['price']

features_valid = df_ohe_valid.drop(['price'], axis=1)
target_valid = df_ohe_valid['price']

features_test = df_ohe_test.drop(['price'], axis=1)
target_test = df_ohe_test['price']

# %% [markdown]
# ## Linear Regression

# %%
# %%time

model = LinearRegression()
model.fit(features_train, target_train)
# Out:
# CPU times: user 9.78 s, sys: 2.76 s, total: 12.5 s
# Wall time: 15.1 s
# LinearRegression()

# %%
# %%time

pred_train = model.predict(features_train)
pred_valid = model.predict(features_valid)
pred_test = model.predict(features_test)

print("Train RSME:", rmse(target_train, pred_train).round(5))
print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
print("Test RSME:", rmse(target_test, pred_test).round(5))
# Out:
# Train RSME: 2621.65006
# Valid RSME: 2612.76508
# Test RSME: 2626.50956
# CPU times: user 712 ms, sys: 726 ms, total: 1.44 s
# Wall time: 1.91 s

# %% [markdown]
# **Linear Regression**
#
# Training Time
#
# The training of the linear regression model took approximately 12.5 seconds, reflecting moderate computational requirements.
#
# Prediction Speed
#
# The prediction phase for the linear regression model was relatively fast, with predictions for all datasets (train, validation, and test) completed in approximately 1.44 seconds.
#
# Prediction Quality
#
# The performance metrics for the model on different datasets are as follows:
#   * Train RSME: 2621.65006
#   * Valid RSME: 2612.76508
#   * Test RSME: 2626.50956
#
# The Root Mean Squared Error (RSME) values indicate the average deviation of predicted car prices from actual prices. Despite the model's fast prediction speed, the RSME values suggest that the model's predictive accuracy could be improved.
#
# **Conclusion**
#
# The linear regression model demonstrates moderate computational efficiency and fast prediction speed. However, the model's predictive accuracy, as indicated by RSME values, suggests room for improvement. Further refinement or exploration of alternative models may be necessary to enhance prediction quality for estimating the market value of used cars effectively.

# %% [markdown]
# ## Decision Tree

# %%
for depth in [1, 2, 4, 6, 8, None]:
    model = DecisionTreeRegressor(max_depth=depth)
    model.fit(features_train, target_train)

    pred_train = model.predict(features_train)
    pred_valid = model.predict(features_valid)
    print("Depth:", depth)
    print("Train RSME:", rmse(target_train, pred_train).round(5))
    print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
# Out:
# Depth: 1
# Train RSME: 4233.30031
# Valid RSME: 4216.56961
# Depth: 2
# Train RSME: 3674.29782
# Valid RSME: 3665.96888
# Depth: 4
# Train RSME: 2995.37379
# Valid RSME: 2995.06149
# Depth: 6
# Train RSME: 2570.31782
# Valid RSME: 2564.93774
# Depth: 8
# Train RSME: 2337.52933
# Valid RSME: 2355.04674
# Depth: None
# Train RSME: 555.74643
# Valid RSME: 2286.6301

# %%
# %%time

model = DecisionTreeRegressor(max_depth=8)
model.fit(features_train, target_train)
# Out:
# CPU times: user 4.04 s, sys: 220 ms, total: 4.26 s
# Wall time: 6.08 s
# DecisionTreeRegressor(max_depth=8)

# %%
# %%time

pred_train = model.predict(features_train)
pred_valid = model.predict(features_valid)
pred_test = model.predict(features_test)

print("Train RSME:", rmse(target_train, pred_train).round(5))
print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
print("Test RSME:", rmse(target_test, pred_test).round(5))
# Out:
# Train RSME: 2337.52933
# Valid RSME: 2355.49511
# Test RSME: 2332.23109
# CPU times: user 256 ms, sys: 252 ms, total: 509 ms
# Wall time: 1.49 s

# %% [markdown]
# **Decision Tree**
#
# Hyperparameter Tuning
#
# The decision tree model was trained with different maximum depths ranging from 1 to 8, including an unlimited depth (None). The model's performance was evaluated based on the Root Mean Squared Error (RSME) metric on both the training and validation datasets.
#
# * Depth: 1
#   * Train RSME: 4233.30031
#   * Valid RSME: 4216.56961
# * Depth: 2
#   * Train RSME: 3674.29782
#   * Valid RSME: 3665.96888
# * Depth: 4
#   * Train RSME: 2995.37379
#   * Valid RSME: 2995.06149
# * Depth: 6
#   * Train RSME: 2570.31782
#   * Valid RSME: 2564.93774
# * Depth: 8
#   * Train RSME: 2337.52933
#   * Valid RSME: 2355.04674
# * Depth: None
#   * Train RSME: 555.74643
#   * Valid RSME: 2286.6301
#
# The results show that increasing the maximum depth of the decision tree generally improves the model's performance until a certain point. Beyond a depth of 8, the model starts to overfit the training data, as indicated by the substantially lower RSME on the training set compared to the validation set.
#
# **Selected Model Performance**
#
# After tuning the hyperparameters, the decision tree model with a maximum depth of 8 was selected for further evaluation.
#
# Training Time
#
# The training of the selected decision tree model took approximately 4.26 seconds, indicating moderate computational requirements.
#
# Prediction Speed
#
# The prediction phase for the selected decision tree model was relatively fast, with predictions for all datasets (train, validation, and test) completed in approximately 509 milliseconds.
#
# Prediction Quality
#
# The performance metrics for the selected model on different datasets are as follows:
#   * Train RSME: 2337.52933
#   * Valid RSME: 2355.49511
#   * Test RSME: 2332.23109
#
# **Conclusion**
#
# The decision tree model with a maximum depth of 8 demonstrates improved predictive performance compared to shallower trees. However, careful consideration is needed to prevent overfitting, especially when using unlimited depth. The selected model exhibits moderate computational efficiency, fast prediction speed, and reasonably good prediction quality. Further exploration and refinement may be necessary to optimize the model's performance for estimating the market value of used cars accurately.

# %% [markdown]
# ## Random Forest

# %%
for depth in [1, 2, 4, 6, 8, None]:
    model = RandomForestRegressor(max_depth=depth, n_estimators=100)
    model.fit(features_train, target_train)

    pred_train = model.predict(features_train)
    pred_valid = model.predict(features_valid)
    print("Depth:", depth)
    print("Train RSME:", rmse(target_train, pred_train).round(5))
    print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
# Out:
# Depth: 1
# Train RSME: 4233.30059
# Valid RSME: 4216.57011
# Depth: 2
# Train RSME: 3674.09886
# Valid RSME: 3665.84904
# Depth: 4
# Train RSME: 2959.99571
# Valid RSME: 2959.45785
# Depth: 6
# Train RSME: 2521.79589
# Valid RSME: 2517.73965
# Depth: 8
# Train RSME: 2271.81273
# Valid RSME: 2286.67691
# Depth: None
# Train RSME: 833.64133
# Valid RSME: 1817.79793

# %%
# %%time

model = RandomForestRegressor(max_depth=8, n_estimators=100)
model.fit(features_train, target_train)
# Out:
# CPU times: user 3min 13s, sys: 423 ms, total: 3min 13s
# Wall time: 3min 17s
# RandomForestRegressor(max_depth=8)

# %%
# %%time

pred_train = model.predict(features_train)
pred_valid = model.predict(features_valid)
pred_test = model.predict(features_test)

print("Train RSME:", rmse(target_train, pred_train).round(5))
print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
print("Test RSME:", rmse(target_test, pred_test).round(5))
# Out:
# Train RSME: 2271.30481
# Valid RSME: 2285.48254
# Test RSME: 2267.41039
# CPU times: user 2.43 s, sys: 240 ms, total: 2.67 s
# Wall time: 2.69 s

# %% [markdown]
# **Random Forest**
#
# **Hyperparameter Tuning**
#
# The Random Forest model was trained with different maximum depths ranging from 1 to 8, including an unlimited depth (None), while keeping the number of estimators constant at 100. The model's performance was evaluated based on the Root Mean Squared Error (RSME) metric on both the training and validation datasets.
# * Depth: 1
#   * Train RSME: 4233.30059
#   * Valid RSME: 4216.57011
# * Depth: 2
#   * Train RSME: 3674.09886
#   * Valid RSME: 3665.84904
# * Depth: 4
#   * Train RSME: 2959.99571
#   * Valid RSME: 2959.45785
# * Depth: 6
#   * Train RSME: 2521.79589
#   * Valid RSME: 2517.73965
# * Depth: 8
#   * Train RSME: 2271.81273
#   * Valid RSME: 2286.67691
# * Depth: None
#   * Train RSME: 833.64133
#   * Valid RSME: 1817.79793
#
# The results demonstrate that increasing the maximum depth of the Random Forest generally improves the model's performance until a certain point. Beyond a depth of 8, the model starts to overfit the training data, as indicated by the substantially lower RSME on the training set compared to the validation set.
#
# **Selected Model Performance**
#
# After tuning the hyperparameters, the Random Forest model with a maximum depth of 8 was selected for further evaluation, as it achieved a good balance between training and validation RSME.
#
# Training Time
#
# The training of the selected Random Forest model took approximately 3 minutes and 13 seconds, indicating significant computational requirements due to the ensemble nature of the algorithm.
#
# Prediction Speed
#
# The prediction phase for the selected Random Forest model was relatively fast, with predictions for all datasets (train, validation, and test) completed in approximately 2.67 seconds.
#
# Prediction Quality
#
# The performance metrics for the selected model on different datasets are as follows:
#   * Train RSME: 2271.30481
#   * Valid RSME: 2285.48254
#   * Test RSME: 2267.41039
#
# **Conclusion**
#
# The Random Forest model with a maximum depth of 8 demonstrates improved predictive performance compared to shallower trees. However, careful consideration is needed to prevent overfitting, especially when using unlimited depth. The selected model exhibits relatively high computational requirements for training but fast prediction speed and good prediction quality. Further exploration and refinement may be necessary to optimize the model's performance for estimating the market value of used cars accurately.

# %% [markdown]
# ## LGBM - gradient boosting

# %%
# %%time

model = lgb.LGBMRegressor(num_iterations=20, verbose=0, metric='rmse')
model.fit(features_train, target_train, eval_set = (features_valid, target_valid))
# Out:
# /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:172: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# CPU times: user 1.46 s, sys: 398 ms, total: 1.86 s
# Wall time: 1.9 s
# LGBMRegressor(metric='rmse', num_iterations=20, verbose=0)

# %%
# %%time

pred_train = model.predict(features_train)
pred_valid = model.predict(features_valid)
pred_test = model.predict(features_test)

print("Train RSME:", rmse(target_train, pred_train).round(5))
print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
print("Test RSME:", rmse(target_test, pred_test).round(5))
# Out:
# Train RSME: 2318.12303
# Valid RSME: 2310.86439
# Test RSME: 2296.99548
# CPU times: user 740 ms, sys: 322 ms, total: 1.06 s
# Wall time: 1.05 s

# %% [markdown]
# **LightGBM (Gradient Boosting)**
#
# Training Time
#
# The LightGBM (Gradient Boosting) model was trained with 20 iterations. The training process took approximately 1.86 seconds, reflecting the efficiency of the LightGBM algorithm in handling gradient boosting.
#
# Prediction Speed
#
# The prediction phase for the LightGBM model was remarkably fast, with predictions for all datasets (train, validation, and test) completed in approximately 1.06 seconds. This showcases the model's efficiency in generating predictions.
#
# Prediction Quality
#
# The performance metrics for the LightGBM model on different datasets are as follows:
#   * Train RSME: 2318.12303
#   * Valid RSME: 2310.86439
#   * Test RSME: 2296.99548
#
# The Root Mean Squared Error (RSME) values indicate the average deviation of predicted car prices from actual prices. The LightGBM model demonstrates competitive predictive accuracy on all datasets, with relatively low RSME values.
#
# **Conclusion**
#
# The LightGBM (Gradient Boosting) model showcases impressive performance in terms of training time, prediction speed, and prediction quality. With its efficient handling of gradient boosting and low computational requirements, LightGBM emerges as a promising candidate for estimating the market value of used cars accurately and efficiently. Further optimization and fine-tuning may enhance the model's performance, but its current performance already demonstrates its suitability for deployment in real-world applications.

# %% [markdown]
# ## Catboost

# %%
# %%time
model = cb.CatBoostRegressor()
model.fit(features_train, target_train)
# Out:
# Learning rate set to 0.088531
# 0:	learn: 4504.2312923	total: 86.1ms	remaining: 1m 26s
# 1:	learn: 4279.3148911	total: 108ms	remaining: 53.7s
# 2:	learn: 4067.5983087	total: 128ms	remaining: 42.7s
# 3:	learn: 3880.9847746	total: 150ms	remaining: 37.3s
# 4:	learn: 3723.6657810	total: 171ms	remaining: 34.1s
# 5:	learn: 3576.8962937	total: 194ms	remaining: 32.1s
# 6:	learn: 3443.5860923	total: 215ms	remaining: 30.5s
# 7:	learn: 3322.5024965	total: 242ms	remaining: 30s
# 8:	learn: 3220.3252466	total: 265ms	remaining: 29.2s
# 9:	learn: 3125.9721177	total: 289ms	remaining: 28.6s
# 10:	learn: 3042.7049930	total: 313ms	remaining: 28.1s
# 11:	learn: 2969.5811542	total: 336ms	remaining: 27.6s
# 12:	learn: 2897.3775238	total: 356ms	remaining: 27.1s
# 13:	learn: 2839.8480576	total: 376ms	remaining: 26.5s
# 14:	learn: 2785.6200909	total: 396ms	remaining: 26s
# 15:	learn: 2736.6506406	total: 417ms	remaining: 25.7s
# 16:	learn: 2694.5428109	total: 447ms	remaining: 25.8s
# 17:	learn: 2654.1088662	total: 470ms	remaining: 25.6s
# 18:	learn: 2618.9570842	total: 492ms	remaining: 25.4s
# 19:	learn: 2586.4993300	total: 517ms	remaining: 25.3s
# 20:	learn: 2555.9693937	total: 538ms	remaining: 25.1s
# 21:	learn: 2529.1957250	total: 563ms	remaining: 25s
# 22:	learn: 2505.7231047	total: 583ms	remaining: 24.7s
# 23:	learn: 2483.1447074	total: 603ms	remaining: 24.5s
# 24:	learn: 2460.4347474	total: 624ms	remaining: 24.3s
# 25:	learn: 2440.0956505	total: 644ms	remaining: 24.1s
# 26:	learn: 2413.9090238	total: 665ms	remaining: 24s
# 27:	learn: 2392.8253251	total: 685ms	remaining: 23.8s
# 28:	learn: 2375.9263661	total: 712ms	remaining: 23.8s
# 29:	learn: 2359.6694554	total: 731ms	remaining: 23.6s
# 30:	learn: 2346.8084352	total: 751ms	remaining: 23.5s
# 31:	learn: 2333.5476592	total: 773ms	remaining: 23.4s
# 32:	learn: 2319.8352722	total: 792ms	remaining: 23.2s
# 33:	learn: 2308.7325185	total: 814ms	remaining: 23.1s
# 34:	learn: 2296.8341984	total: 836ms	remaining: 23.1s
# 35:	learn: 2286.6124743	total: 860ms	remaining: 23s
# 36:	learn: 2275.5496454	total: 889ms	remaining: 23.1s
# 37:	learn: 2267.3375855	total: 920ms	remaining: 23.3s
# 38:	learn: 2259.4396544	total: 960ms	remaining: 23.7s
# 39:	learn: 2250.3729319	total: 984ms	remaining: 23.6s
# 40:	learn: 2242.8109529	total: 1s	remaining: 23.5s
# 41:	learn: 2233.6012018	total: 1.02s	remaining: 23.3s
# 42:	learn: 2226.7663675	total: 1.04s	remaining: 23.2s
# 43:	learn: 2219.2979784	total: 1.06s	remaining: 23.2s
# 44:	learn: 2213.1134509	total: 1.08s	remaining: 23s
# 45:	learn: 2206.1236997	total: 1.1s	remaining: 22.9s
# 46:	learn: 2201.0884301	total: 1.13s	remaining: 22.9s
# 47:	learn: 2194.3537747	total: 1.15s	remaining: 22.8s
# 48:	learn: 2189.7685846	total: 1.18s	remaining: 22.8s
# 49:	learn: 2185.0232389	total: 1.19s	remaining: 22.7s
# 50:	learn: 2180.4162400	total: 1.21s	remaining: 22.6s
# 51:	learn: 2176.6490062	total: 1.23s	remaining: 22.5s
# 52:	learn: 2172.6217595	total: 1.25s	remaining: 22.4s
# 53:	learn: 2168.5015029	total: 1.27s	remaining: 22.3s
# 54:	learn: 2163.5729769	total: 1.29s	remaining: 22.2s
# 55:	learn: 2160.3995720	total: 1.31s	remaining: 22.1s
# 56:	learn: 2156.1776641	total: 1.33s	remaining: 22s
# 57:	learn: 2152.0231192	total: 1.35s	remaining: 22s
# 58:	learn: 2148.3357048	total: 1.38s	remaining: 22s
# 59:	learn: 2144.1680879	total: 1.4s	remaining: 21.9s
# 60:	learn: 2140.9165374	total: 1.43s	remaining: 22s
# 61:	learn: 2138.2161814	total: 1.45s	remaining: 21.9s
# 62:	learn: 2135.3794612	total: 1.47s	remaining: 21.8s
# 63:	learn: 2133.2370666	total: 1.48s	remaining: 21.7s
# 64:	learn: 2128.8424262	total: 1.5s	remaining: 21.6s
# 65:	learn: 2125.4091423	total: 1.52s	remaining: 21.6s
# 66:	learn: 2123.4109944	total: 1.55s	remaining: 21.5s
# 67:	learn: 2121.5939365	total: 1.56s	remaining: 21.5s
# 68:	learn: 2118.2145129	total: 1.58s	remaining: 21.4s
# 69:	learn: 2115.3818387	total: 1.6s	remaining: 21.3s
# 70:	learn: 2112.5115808	total: 1.62s	remaining: 21.2s
# 71:	learn: 2110.2777865	total: 1.64s	remaining: 21.2s
# 72:	learn: 2106.3850234	total: 1.66s	remaining: 21.1s
# 73:	learn: 2103.9159648	total: 1.68s	remaining: 21s
# 74:	learn: 2101.4953905	total: 1.7s	remaining: 21s
# 75:	learn: 2099.9347738	total: 1.72s	remaining: 20.9s
# 76:	learn: 2097.8546361	total: 1.74s	remaining: 20.9s
# 77:	learn: 2095.7074883	total: 1.77s	remaining: 20.9s
# 78:	learn: 2091.9139074	total: 1.79s	remaining: 20.8s
# 79:	learn: 2090.2471603	total: 1.8s	remaining: 20.8s
# 80:	learn: 2088.3931635	total: 1.82s	remaining: 20.7s
# 81:	learn: 2086.9458049	total: 1.84s	remaining: 20.6s
# 82:	learn: 2084.4645273	total: 1.86s	remaining: 20.6s
# 83:	learn: 2081.4932532	total: 1.88s	remaining: 20.5s
# 84:	learn: 2079.4246135	total: 1.91s	remaining: 20.5s
# 85:	learn: 2077.4390771	total: 1.93s	remaining: 20.5s
# 86:	learn: 2076.2172260	total: 1.97s	remaining: 20.7s
# 87:	learn: 2073.8805912	total: 1.99s	remaining: 20.6s
# 88:	learn: 2071.0242914	total: 2.01s	remaining: 20.6s
# 89:	learn: 2069.8562098	total: 2.03s	remaining: 20.5s
# 90:	learn: 2067.2155214	total: 2.05s	remaining: 20.5s
# 91:	learn: 2065.0072667	total: 2.07s	remaining: 20.4s
# 92:	learn: 2063.7341411	total: 2.09s	remaining: 20.4s
# 93:	learn: 2062.4026147	total: 2.11s	remaining: 20.3s
# 94:	learn: 2060.6832174	total: 2.13s	remaining: 20.3s
# 95:	learn: 2059.4485965	total: 2.15s	remaining: 20.2s
# 96:	learn: 2057.5665791	total: 2.17s	remaining: 20.2s
# 97:	learn: 2056.0101483	total: 2.19s	remaining: 20.2s
# 98:	learn: 2054.7780032	total: 2.21s	remaining: 20.1s
# 99:	learn: 2053.6625111	total: 2.23s	remaining: 20.1s
# 100:	learn: 2052.7714233	total: 2.25s	remaining: 20.1s
# 101:	learn: 2050.4748969	total: 2.27s	remaining: 20s
# 102:	learn: 2049.5424958	total: 2.29s	remaining: 20s
# 103:	learn: 2047.5890342	total: 2.31s	remaining: 19.9s
# 104:	learn: 2046.2650130	total: 2.33s	remaining: 19.9s
# 105:	learn: 2045.3364108	total: 2.35s	remaining: 19.8s
# 106:	learn: 2043.6915125	total: 2.37s	remaining: 19.8s
# 107:	learn: 2042.2154098	total: 2.4s	remaining: 19.8s
# 108:	learn: 2040.8307380	total: 2.42s	remaining: 19.8s
# 109:	learn: 2039.7266060	total: 2.44s	remaining: 19.7s
# 110:	learn: 2038.6237486	total: 2.45s	remaining: 19.7s
# 111:	learn: 2037.4632929	total: 2.48s	remaining: 19.6s
# 112:	learn: 2035.9824914	total: 2.49s	remaining: 19.6s
# 113:	learn: 2034.2455435	total: 2.52s	remaining: 19.5s
# 114:	learn: 2033.3798867	total: 2.54s	remaining: 19.5s
# 115:	learn: 2032.0852499	total: 2.56s	remaining: 19.5s
# 116:	learn: 2029.6276380	total: 2.58s	remaining: 19.5s
# 117:	learn: 2028.4007458	total: 2.6s	remaining: 19.4s
# 118:	learn: 2027.7298185	total: 2.62s	remaining: 19.4s
# 119:	learn: 2025.5427289	total: 2.64s	remaining: 19.4s
# 120:	learn: 2024.1207549	total: 2.66s	remaining: 19.3s
# 121:	learn: 2022.2958242	total: 2.69s	remaining: 19.3s
# 122:	learn: 2021.1400430	total: 2.71s	remaining: 19.3s
# 123:	learn: 2019.6874225	total: 2.73s	remaining: 19.3s
# 124:	learn: 2018.2983235	total: 2.75s	remaining: 19.2s
# 125:	learn: 2017.6544077	total: 2.77s	remaining: 19.2s
# 126:	learn: 2016.5952237	total: 2.8s	remaining: 19.2s
# 127:	learn: 2015.6294197	total: 2.84s	remaining: 19.3s
# 128:	learn: 2013.8279317	total: 2.86s	remaining: 19.3s
# 129:	learn: 2012.5077286	total: 2.89s	remaining: 19.4s
# 130:	learn: 2010.9069970	total: 2.94s	remaining: 19.5s
# 131:	learn: 2009.9614883	total: 2.99s	remaining: 19.7s
# 132:	learn: 2009.2091844	total: 3.02s	remaining: 19.7s
# 133:	learn: 2007.8692377	total: 3.07s	remaining: 19.9s
# 134:	learn: 2007.0720357	total: 3.12s	remaining: 20s
# 135:	learn: 2006.4447319	total: 3.15s	remaining: 20s
# 136:	learn: 2005.7936367	total: 3.2s	remaining: 20.2s
# 137:	learn: 2004.4617403	total: 3.25s	remaining: 20.3s
# 138:	learn: 2003.3412257	total: 3.3s	remaining: 20.5s
# 139:	learn: 2001.6970810	total: 3.33s	remaining: 20.5s
# 140:	learn: 2000.5802674	total: 3.38s	remaining: 20.6s
# 141:	learn: 1999.6623193	total: 3.43s	remaining: 20.7s
# 142:	learn: 1998.8892437	total: 3.48s	remaining: 20.9s
# 143:	learn: 1998.0270230	total: 3.54s	remaining: 21.1s
# 144:	learn: 1996.4381837	total: 3.6s	remaining: 21.2s
# 145:	learn: 1995.3562296	total: 3.65s	remaining: 21.3s
# 146:	learn: 1994.6447598	total: 3.67s	remaining: 21.3s
# 147:	learn: 1993.8797045	total: 3.7s	remaining: 21.3s
# 148:	learn: 1992.9258064	total: 3.72s	remaining: 21.3s
# 149:	learn: 1992.1864429	total: 3.75s	remaining: 21.3s
# 150:	learn: 1990.9804828	total: 3.77s	remaining: 21.2s
# 151:	learn: 1990.1482303	total: 3.79s	remaining: 21.2s
# 152:	learn: 1989.4282897	total: 3.81s	remaining: 21.1s
# 153:	learn: 1988.6797043	total: 3.85s	remaining: 21.1s
# 154:	learn: 1987.3108371	total: 3.9s	remaining: 21.3s
# 155:	learn: 1986.3317531	total: 3.94s	remaining: 21.3s
# 156:	learn: 1985.3804224	total: 3.99s	remaining: 21.4s
# 157:	learn: 1984.4464726	total: 4.03s	remaining: 21.5s
# 158:	learn: 1983.5655068	total: 4.08s	remaining: 21.6s
# 159:	learn: 1982.8599863	total: 4.12s	remaining: 21.6s
# 160:	learn: 1981.7284088	total: 4.16s	remaining: 21.7s
# 161:	learn: 1980.7331857	total: 4.21s	remaining: 21.8s
# 162:	learn: 1980.1580091	total: 4.25s	remaining: 21.8s
# 163:	learn: 1979.4360470	total: 4.29s	remaining: 21.9s
# 164:	learn: 1978.5791532	total: 4.33s	remaining: 21.9s
# 165:	learn: 1977.8282325	total: 4.36s	remaining: 21.9s
# 166:	learn: 1977.1050432	total: 4.4s	remaining: 22s
# 167:	learn: 1976.3602813	total: 4.43s	remaining: 21.9s
# 168:	learn: 1975.9706742	total: 4.47s	remaining: 22s
# 169:	learn: 1975.0410277	total: 4.52s	remaining: 22.1s
# 170:	learn: 1974.0999677	total: 4.56s	remaining: 22.1s
# 171:	learn: 1973.0829102	total: 4.6s	remaining: 22.2s
# 172:	learn: 1972.3290304	total: 4.64s	remaining: 22.2s
# 173:	learn: 1971.4960545	total: 4.66s	remaining: 22.1s
# 174:	learn: 1970.1566577	total: 4.71s	remaining: 22.2s
# 175:	learn: 1969.3679440	total: 4.75s	remaining: 22.3s
# 176:	learn: 1968.4607316	total: 4.81s	remaining: 22.3s
# 177:	learn: 1967.9398755	total: 4.87s	remaining: 22.5s
# 178:	learn: 1967.3882491	total: 4.92s	remaining: 22.6s
# 179:	learn: 1966.2997466	total: 4.96s	remaining: 22.6s
# 180:	learn: 1965.0754900	total: 5.02s	remaining: 22.7s
# 181:	learn: 1964.6091339	total: 5.09s	remaining: 22.9s
# 182:	learn: 1963.8668951	total: 5.14s	remaining: 23s
# 183:	learn: 1963.0136491	total: 5.19s	remaining: 23s
# 184:	learn: 1962.1052691	total: 5.22s	remaining: 23s
# 185:	learn: 1961.4681263	total: 5.25s	remaining: 23s
# 186:	learn: 1961.0952105	total: 5.29s	remaining: 23s
# 187:	learn: 1960.5734299	total: 5.34s	remaining: 23s
# 188:	learn: 1959.8948185	total: 5.38s	remaining: 23.1s
# 189:	learn: 1959.0701563	total: 5.43s	remaining: 23.2s
# 190:	learn: 1958.2833747	total: 5.48s	remaining: 23.2s
# 191:	learn: 1957.7190130	total: 5.54s	remaining: 23.3s
# 192:	learn: 1956.9990305	total: 5.59s	remaining: 23.4s
# 193:	learn: 1956.5819851	total: 5.64s	remaining: 23.4s
# 194:	learn: 1955.8873788	total: 5.69s	remaining: 23.5s
# 195:	learn: 1955.1434346	total: 5.73s	remaining: 23.5s
# 196:	learn: 1954.3548948	total: 5.77s	remaining: 23.5s
# 197:	learn: 1953.8266831	total: 5.82s	remaining: 23.6s
# 198:	learn: 1953.2279984	total: 5.87s	remaining: 23.6s
# 199:	learn: 1952.6109604	total: 5.91s	remaining: 23.6s
# 200:	learn: 1951.5653338	total: 5.94s	remaining: 23.6s
# 201:	learn: 1951.0571717	total: 5.96s	remaining: 23.5s
# 202:	learn: 1950.1158949	total: 5.99s	remaining: 23.5s
# 203:	learn: 1949.1914898	total: 6.03s	remaining: 23.5s
# 204:	learn: 1947.9090849	total: 6.07s	remaining: 23.5s
# 205:	learn: 1947.2710728	total: 6.12s	remaining: 23.6s
# 206:	learn: 1946.7451980	total: 6.15s	remaining: 23.6s
# 207:	learn: 1945.8427748	total: 6.21s	remaining: 23.7s
# 208:	learn: 1945.1403253	total: 6.27s	remaining: 23.7s
# 209:	learn: 1944.3670666	total: 6.32s	remaining: 23.8s
# 210:	learn: 1943.9504507	total: 6.37s	remaining: 23.8s
# 211:	learn: 1942.8625999	total: 6.43s	remaining: 23.9s
# 212:	learn: 1941.9199779	total: 6.47s	remaining: 23.9s
# 213:	learn: 1941.4770725	total: 6.51s	remaining: 23.9s
# 214:	learn: 1940.7049308	total: 6.57s	remaining: 24s
# 215:	learn: 1940.2423184	total: 6.63s	remaining: 24.1s
# 216:	learn: 1939.5808669	total: 6.68s	remaining: 24.1s
# 217:	learn: 1938.6352233	total: 6.72s	remaining: 24.1s
# 218:	learn: 1938.3583787	total: 6.76s	remaining: 24.1s
# 219:	learn: 1937.5623108	total: 6.82s	remaining: 24.2s
# 220:	learn: 1936.7480735	total: 6.87s	remaining: 24.2s
# 221:	learn: 1936.4081634	total: 6.91s	remaining: 24.2s
# 222:	learn: 1936.0066574	total: 6.95s	remaining: 24.2s
# 223:	learn: 1935.4982915	total: 6.97s	remaining: 24.2s
# 224:	learn: 1934.9658937	total: 6.99s	remaining: 24.1s
# 225:	learn: 1934.3818754	total: 7.01s	remaining: 24s
# 226:	learn: 1933.9914221	total: 7.04s	remaining: 24s
# 227:	learn: 1933.2784048	total: 7.06s	remaining: 23.9s
# 228:	learn: 1932.6499372	total: 7.08s	remaining: 23.8s
# 229:	learn: 1931.8479661	total: 7.1s	remaining: 23.8s
# 230:	learn: 1930.7701952	total: 7.14s	remaining: 23.8s
# 231:	learn: 1930.3765003	total: 7.16s	remaining: 23.7s
# 232:	learn: 1929.8014760	total: 7.18s	remaining: 23.6s
# 233:	learn: 1929.0293499	total: 7.2s	remaining: 23.6s
# 234:	learn: 1928.3174300	total: 7.22s	remaining: 23.5s
# 235:	learn: 1928.0210566	total: 7.24s	remaining: 23.4s
# 236:	learn: 1927.2619915	total: 7.26s	remaining: 23.4s
# 237:	learn: 1926.6410736	total: 7.28s	remaining: 23.3s
# 238:	learn: 1925.7837526	total: 7.31s	remaining: 23.3s
# 239:	learn: 1925.3589559	total: 7.33s	remaining: 23.2s
# 240:	learn: 1924.8795603	total: 7.35s	remaining: 23.1s
# 241:	learn: 1924.4907168	total: 7.37s	remaining: 23.1s
# 242:	learn: 1924.0613954	total: 7.39s	remaining: 23s
# 243:	learn: 1923.2194754	total: 7.41s	remaining: 23s
# 244:	learn: 1922.8353467	total: 7.43s	remaining: 22.9s
# 245:	learn: 1922.3608438	total: 7.45s	remaining: 22.8s
# 246:	learn: 1921.7500956	total: 7.47s	remaining: 22.8s
# 247:	learn: 1921.1670692	total: 7.49s	remaining: 22.7s
# 248:	learn: 1920.7417253	total: 7.5s	remaining: 22.6s
# 249:	learn: 1919.7969173	total: 7.53s	remaining: 22.6s
# 250:	learn: 1919.3234922	total: 7.55s	remaining: 22.5s
# 251:	learn: 1918.6704613	total: 7.57s	remaining: 22.5s
# 252:	learn: 1918.1802173	total: 7.58s	remaining: 22.4s
# 253:	learn: 1917.6098257	total: 7.6s	remaining: 22.3s
# 254:	learn: 1916.9547113	total: 7.62s	remaining: 22.3s
# 255:	learn: 1916.3735973	total: 7.65s	remaining: 22.2s
# 256:	learn: 1915.7954762	total: 7.67s	remaining: 22.2s
# 257:	learn: 1915.2326062	total: 7.69s	remaining: 22.1s
# 258:	learn: 1914.6204368	total: 7.71s	remaining: 22s
# 259:	learn: 1914.2586999	total: 7.72s	remaining: 22s
# 260:	learn: 1913.9075769	total: 7.75s	remaining: 21.9s
# 261:	learn: 1913.2919160	total: 7.77s	remaining: 21.9s
# 262:	learn: 1912.9367835	total: 7.79s	remaining: 21.8s
# 263:	learn: 1912.5023712	total: 7.8s	remaining: 21.8s
# 264:	learn: 1911.7992028	total: 7.83s	remaining: 21.7s
# 265:	learn: 1911.1682276	total: 7.85s	remaining: 21.7s
# 266:	learn: 1910.7202126	total: 7.87s	remaining: 21.6s
# 267:	learn: 1910.2047343	total: 7.89s	remaining: 21.6s
# 268:	learn: 1909.9534349	total: 7.91s	remaining: 21.5s
# 269:	learn: 1909.1710810	total: 7.93s	remaining: 21.4s
# 270:	learn: 1908.8493855	total: 7.95s	remaining: 21.4s
# 271:	learn: 1908.4914744	total: 7.97s	remaining: 21.3s
# 272:	learn: 1907.7741023	total: 8s	remaining: 21.3s
# 273:	learn: 1907.2948666	total: 8.02s	remaining: 21.2s
# 274:	learn: 1906.6860997	total: 8.03s	remaining: 21.2s
# 275:	learn: 1905.8873378	total: 8.05s	remaining: 21.1s
# 276:	learn: 1905.4723661	total: 8.07s	remaining: 21.1s
# 277:	learn: 1904.9512309	total: 8.09s	remaining: 21s
# 278:	learn: 1904.4536739	total: 8.11s	remaining: 21s
# 279:	learn: 1903.8870560	total: 8.14s	remaining: 20.9s
# 280:	learn: 1903.5792996	total: 8.17s	remaining: 20.9s
# 281:	learn: 1903.2140688	total: 8.19s	remaining: 20.9s
# 282:	learn: 1902.6920075	total: 8.21s	remaining: 20.8s
# 283:	learn: 1902.2976943	total: 8.23s	remaining: 20.8s
# 284:	learn: 1901.7567946	total: 8.25s	remaining: 20.7s
# 285:	learn: 1901.3142055	total: 8.27s	remaining: 20.7s
# 286:	learn: 1900.8401107	total: 8.3s	remaining: 20.6s
# 287:	learn: 1900.4647403	total: 8.31s	remaining: 20.6s
# 288:	learn: 1899.7498294	total: 8.33s	remaining: 20.5s
# 289:	learn: 1899.2893790	total: 8.35s	remaining: 20.5s
# 290:	learn: 1898.8202942	total: 8.38s	remaining: 20.4s
# 291:	learn: 1898.4716200	total: 8.4s	remaining: 20.4s
# 292:	learn: 1898.2436559	total: 8.42s	remaining: 20.3s
# 293:	learn: 1897.7006509	total: 8.45s	remaining: 20.3s
# 294:	learn: 1897.1179485	total: 8.47s	remaining: 20.2s
# 295:	learn: 1896.8054196	total: 8.49s	remaining: 20.2s
# 296:	learn: 1896.1207521	total: 8.51s	remaining: 20.1s
# 297:	learn: 1895.8355771	total: 8.53s	remaining: 20.1s
# 298:	learn: 1895.4591671	total: 8.55s	remaining: 20.1s
# 299:	learn: 1895.1697728	total: 8.59s	remaining: 20s
# 300:	learn: 1894.7982368	total: 8.61s	remaining: 20s
# 301:	learn: 1894.4275340	total: 8.63s	remaining: 19.9s
# 302:	learn: 1894.2143428	total: 8.64s	remaining: 19.9s
# 303:	learn: 1893.8483352	total: 8.66s	remaining: 19.8s
# 304:	learn: 1893.2860842	total: 8.68s	remaining: 19.8s
# 305:	learn: 1893.0549248	total: 8.7s	remaining: 19.7s
# 306:	learn: 1892.6582962	total: 8.71s	remaining: 19.7s
# 307:	learn: 1892.2923915	total: 8.73s	remaining: 19.6s
# 308:	learn: 1891.8783473	total: 8.74s	remaining: 19.6s
# 309:	learn: 1891.3626858	total: 8.76s	remaining: 19.5s
# 310:	learn: 1891.0470455	total: 8.78s	remaining: 19.4s
# 311:	learn: 1890.4658375	total: 8.8s	remaining: 19.4s
# 312:	learn: 1890.0152331	total: 8.82s	remaining: 19.4s
# 313:	learn: 1889.6211863	total: 8.84s	remaining: 19.3s
# 314:	learn: 1889.1844277	total: 8.86s	remaining: 19.3s
# 315:	learn: 1888.6901030	total: 8.87s	remaining: 19.2s
# 316:	learn: 1888.0877117	total: 8.89s	remaining: 19.2s
# 317:	learn: 1887.5377512	total: 8.91s	remaining: 19.1s
# 318:	learn: 1887.0244368	total: 8.93s	remaining: 19.1s
# 319:	learn: 1886.7579663	total: 8.94s	remaining: 19s
# 320:	learn: 1886.4058706	total: 8.96s	remaining: 18.9s
# 321:	learn: 1886.2218159	total: 8.97s	remaining: 18.9s
# 322:	learn: 1885.7073907	total: 8.99s	remaining: 18.8s
# 323:	learn: 1885.3052338	total: 9.01s	remaining: 18.8s
# 324:	learn: 1884.9839836	total: 9.03s	remaining: 18.8s
# 325:	learn: 1884.6083730	total: 9.05s	remaining: 18.7s
# 326:	learn: 1884.2244649	total: 9.07s	remaining: 18.7s
# 327:	learn: 1883.9780029	total: 9.09s	remaining: 18.6s
# 328:	learn: 1883.7238616	total: 9.1s	remaining: 18.6s
# 329:	learn: 1883.5127768	total: 9.12s	remaining: 18.5s
# 330:	learn: 1883.0480091	total: 9.14s	remaining: 18.5s
# 331:	learn: 1882.8080551	total: 9.17s	remaining: 18.4s
# 332:	learn: 1882.0385628	total: 9.19s	remaining: 18.4s
# 333:	learn: 1881.6081699	total: 9.2s	remaining: 18.4s
# 334:	learn: 1881.2435316	total: 9.22s	remaining: 18.3s
# 335:	learn: 1880.8502512	total: 9.24s	remaining: 18.3s
# 336:	learn: 1880.2967628	total: 9.26s	remaining: 18.2s
# 337:	learn: 1879.6598986	total: 9.28s	remaining: 18.2s
# 338:	learn: 1879.1933884	total: 9.3s	remaining: 18.1s
# 339:	learn: 1878.7986357	total: 9.31s	remaining: 18.1s
# 340:	learn: 1878.5386515	total: 9.33s	remaining: 18s
# 341:	learn: 1878.1564700	total: 9.35s	remaining: 18s
# 342:	learn: 1877.7069597	total: 9.36s	remaining: 17.9s
# 343:	learn: 1877.4348491	total: 9.38s	remaining: 17.9s
# 344:	learn: 1877.0813408	total: 9.4s	remaining: 17.8s
# 345:	learn: 1876.2741759	total: 9.42s	remaining: 17.8s
# 346:	learn: 1876.0225182	total: 9.44s	remaining: 17.8s
# 347:	learn: 1875.7041685	total: 9.45s	remaining: 17.7s
# 348:	learn: 1875.2193371	total: 9.47s	remaining: 17.7s
# 349:	learn: 1874.8623713	total: 9.49s	remaining: 17.6s
# 350:	learn: 1874.5176996	total: 9.5s	remaining: 17.6s
# 351:	learn: 1874.3016319	total: 9.52s	remaining: 17.5s
# 352:	learn: 1873.8118147	total: 9.54s	remaining: 17.5s
# 353:	learn: 1873.5018428	total: 9.55s	remaining: 17.4s
# 354:	learn: 1873.3131445	total: 9.57s	remaining: 17.4s
# 355:	learn: 1872.7134564	total: 9.59s	remaining: 17.3s
# 356:	learn: 1872.4765160	total: 9.61s	remaining: 17.3s
# 357:	learn: 1872.2431319	total: 9.62s	remaining: 17.3s
# 358:	learn: 1871.6508631	total: 9.64s	remaining: 17.2s
# 359:	learn: 1871.2897625	total: 9.66s	remaining: 17.2s
# 360:	learn: 1870.9743788	total: 9.68s	remaining: 17.1s
# 361:	learn: 1870.5516721	total: 9.69s	remaining: 17.1s
# 362:	learn: 1870.1347561	total: 9.71s	remaining: 17s
# 363:	learn: 1869.6916720	total: 9.73s	remaining: 17s
# 364:	learn: 1869.3403221	total: 9.75s	remaining: 17s
# 365:	learn: 1869.0558499	total: 9.76s	remaining: 16.9s
# 366:	learn: 1868.5221101	total: 9.78s	remaining: 16.9s
# 367:	learn: 1868.1488600	total: 9.8s	remaining: 16.8s
# 368:	learn: 1867.7478406	total: 9.82s	remaining: 16.8s
# 369:	learn: 1867.5749643	total: 9.83s	remaining: 16.7s
# 370:	learn: 1867.1821932	total: 9.86s	remaining: 16.7s
# 371:	learn: 1866.8283049	total: 9.87s	remaining: 16.7s
# 372:	learn: 1866.5443186	total: 9.89s	remaining: 16.6s
# 373:	learn: 1866.2881411	total: 9.91s	remaining: 16.6s
# 374:	learn: 1866.0919930	total: 9.92s	remaining: 16.5s
# 375:	learn: 1865.7254045	total: 9.94s	remaining: 16.5s
# 376:	learn: 1865.4339173	total: 9.96s	remaining: 16.5s
# 377:	learn: 1865.1212592	total: 9.97s	remaining: 16.4s
# 378:	learn: 1864.7625072	total: 9.99s	remaining: 16.4s
# 379:	learn: 1864.3799835	total: 10s	remaining: 16.3s
# 380:	learn: 1863.9195929	total: 10s	remaining: 16.3s
# 381:	learn: 1863.4804552	total: 10s	remaining: 16.3s
# 382:	learn: 1863.1423332	total: 10.1s	remaining: 16.2s
# 383:	learn: 1862.8941973	total: 10.1s	remaining: 16.2s
# 384:	learn: 1862.4762645	total: 10.1s	remaining: 16.1s
# 385:	learn: 1862.3145198	total: 10.1s	remaining: 16.1s
# 386:	learn: 1861.8895356	total: 10.1s	remaining: 16.1s
# 387:	learn: 1861.3763912	total: 10.2s	remaining: 16s
# 388:	learn: 1861.1502898	total: 10.2s	remaining: 16s
# 389:	learn: 1860.9033545	total: 10.2s	remaining: 16s
# 390:	learn: 1860.5030441	total: 10.2s	remaining: 15.9s
# 391:	learn: 1860.3348520	total: 10.2s	remaining: 15.9s
# 392:	learn: 1860.1515170	total: 10.3s	remaining: 15.8s
# 393:	learn: 1859.7609605	total: 10.3s	remaining: 15.8s
# 394:	learn: 1859.4918040	total: 10.3s	remaining: 15.8s
# 395:	learn: 1859.1722550	total: 10.3s	remaining: 15.7s
# 396:	learn: 1858.8425095	total: 10.3s	remaining: 15.7s
# 397:	learn: 1858.5856403	total: 10.3s	remaining: 15.7s
# 398:	learn: 1858.2038612	total: 10.4s	remaining: 15.6s
# 399:	learn: 1857.9278778	total: 10.4s	remaining: 15.6s
# 400:	learn: 1857.4629782	total: 10.4s	remaining: 15.5s
# 401:	learn: 1857.1629504	total: 10.4s	remaining: 15.5s
# 402:	learn: 1857.0207211	total: 10.4s	remaining: 15.5s
# 403:	learn: 1856.8358651	total: 10.5s	remaining: 15.4s
# 404:	learn: 1856.4732085	total: 10.5s	remaining: 15.4s
# 405:	learn: 1856.0706113	total: 10.5s	remaining: 15.4s
# 406:	learn: 1855.5293207	total: 10.5s	remaining: 15.3s
# 407:	learn: 1855.2012171	total: 10.5s	remaining: 15.3s
# 408:	learn: 1854.8266613	total: 10.5s	remaining: 15.2s
# 409:	learn: 1854.5930874	total: 10.6s	remaining: 15.2s
# 410:	learn: 1854.0905317	total: 10.6s	remaining: 15.2s
# 411:	learn: 1853.8763813	total: 10.6s	remaining: 15.1s
# 412:	learn: 1853.4645249	total: 10.6s	remaining: 15.1s
# 413:	learn: 1853.0762686	total: 10.6s	remaining: 15.1s
# 414:	learn: 1852.7353327	total: 10.7s	remaining: 15s
# 415:	learn: 1852.4272403	total: 10.7s	remaining: 15s
# 416:	learn: 1852.1094120	total: 10.7s	remaining: 14.9s
# 417:	learn: 1851.8914998	total: 10.7s	remaining: 14.9s
# 418:	learn: 1851.5643658	total: 10.7s	remaining: 14.9s
# 419:	learn: 1851.0713022	total: 10.7s	remaining: 14.8s
# 420:	learn: 1850.4984106	total: 10.8s	remaining: 14.8s
# 421:	learn: 1850.3061579	total: 10.8s	remaining: 14.8s
# 422:	learn: 1849.9867907	total: 10.8s	remaining: 14.7s
# 423:	learn: 1849.7138195	total: 10.8s	remaining: 14.7s
# 424:	learn: 1849.5248877	total: 10.8s	remaining: 14.7s
# 425:	learn: 1849.3010623	total: 10.9s	remaining: 14.6s
# 426:	learn: 1849.0806864	total: 10.9s	remaining: 14.6s
# 427:	learn: 1848.8615871	total: 10.9s	remaining: 14.5s
# 428:	learn: 1848.5184997	total: 10.9s	remaining: 14.5s
# 429:	learn: 1848.3144350	total: 10.9s	remaining: 14.5s
# 430:	learn: 1847.9250329	total: 10.9s	remaining: 14.4s
# 431:	learn: 1847.7726504	total: 11s	remaining: 14.4s
# 432:	learn: 1847.4979797	total: 11s	remaining: 14.4s
# 433:	learn: 1847.0504920	total: 11s	remaining: 14.3s
# 434:	learn: 1846.7953018	total: 11s	remaining: 14.3s
# 435:	learn: 1846.5657376	total: 11s	remaining: 14.3s
# 436:	learn: 1846.3028649	total: 11s	remaining: 14.2s
# 437:	learn: 1846.0500826	total: 11.1s	remaining: 14.2s
# 438:	learn: 1845.7534687	total: 11.1s	remaining: 14.2s
# 439:	learn: 1845.5654435	total: 11.1s	remaining: 14.1s
# 440:	learn: 1845.3406953	total: 11.1s	remaining: 14.1s
# 441:	learn: 1845.1484404	total: 11.1s	remaining: 14.1s
# 442:	learn: 1845.0090896	total: 11.1s	remaining: 14s
# 443:	learn: 1844.8008475	total: 11.2s	remaining: 14s
# 444:	learn: 1844.6055754	total: 11.2s	remaining: 14s
# 445:	learn: 1844.3956138	total: 11.2s	remaining: 13.9s
# 446:	learn: 1844.1021715	total: 11.2s	remaining: 13.9s
# 447:	learn: 1843.7609768	total: 11.3s	remaining: 13.9s
# 448:	learn: 1843.4470961	total: 11.3s	remaining: 13.8s
# 449:	learn: 1843.1995631	total: 11.3s	remaining: 13.8s
# 450:	learn: 1842.8971098	total: 11.3s	remaining: 13.8s
# 451:	learn: 1842.5662078	total: 11.3s	remaining: 13.7s
# 452:	learn: 1842.3920886	total: 11.3s	remaining: 13.7s
# 453:	learn: 1842.0116468	total: 11.4s	remaining: 13.7s
# 454:	learn: 1841.8826848	total: 11.4s	remaining: 13.6s
# 455:	learn: 1841.6706772	total: 11.4s	remaining: 13.6s
# 456:	learn: 1841.4203169	total: 11.4s	remaining: 13.6s
# 457:	learn: 1841.2361917	total: 11.4s	remaining: 13.5s
# 458:	learn: 1841.0184972	total: 11.4s	remaining: 13.5s
# 459:	learn: 1840.8577656	total: 11.5s	remaining: 13.5s
# 460:	learn: 1840.6968570	total: 11.5s	remaining: 13.4s
# 461:	learn: 1840.4021250	total: 11.5s	remaining: 13.4s
# 462:	learn: 1840.2012846	total: 11.5s	remaining: 13.3s
# 463:	learn: 1839.5971521	total: 11.5s	remaining: 13.3s
# 464:	learn: 1839.3180404	total: 11.5s	remaining: 13.3s
# 465:	learn: 1838.8122728	total: 11.6s	remaining: 13.3s
# 466:	learn: 1838.5925914	total: 11.6s	remaining: 13.2s
# 467:	learn: 1837.9962492	total: 11.6s	remaining: 13.2s
# 468:	learn: 1837.8538442	total: 11.6s	remaining: 13.2s
# 469:	learn: 1837.6086139	total: 11.6s	remaining: 13.1s
# 470:	learn: 1837.2476475	total: 11.7s	remaining: 13.1s
# 471:	learn: 1836.8815422	total: 11.7s	remaining: 13.1s
# 472:	learn: 1836.5260910	total: 11.7s	remaining: 13s
# 473:	learn: 1836.2477127	total: 11.7s	remaining: 13s
# 474:	learn: 1835.8160452	total: 11.7s	remaining: 13s
# 475:	learn: 1835.5469476	total: 11.7s	remaining: 12.9s
# 476:	learn: 1835.3653894	total: 11.8s	remaining: 12.9s
# 477:	learn: 1835.2104153	total: 11.8s	remaining: 12.9s
# 478:	learn: 1835.0646822	total: 11.8s	remaining: 12.8s
# 479:	learn: 1834.8245719	total: 11.8s	remaining: 12.8s
# 480:	learn: 1834.6817679	total: 11.8s	remaining: 12.8s
# 481:	learn: 1834.5319462	total: 11.8s	remaining: 12.7s
# 482:	learn: 1834.3621507	total: 11.9s	remaining: 12.7s
# 483:	learn: 1834.1190614	total: 11.9s	remaining: 12.7s
# 484:	learn: 1833.9527622	total: 11.9s	remaining: 12.6s
# 485:	learn: 1833.7368393	total: 11.9s	remaining: 12.6s
# 486:	learn: 1833.5497823	total: 11.9s	remaining: 12.6s
# 487:	learn: 1833.2566246	total: 12s	remaining: 12.5s
# 488:	learn: 1833.0232487	total: 12s	remaining: 12.5s
# 489:	learn: 1832.6422764	total: 12s	remaining: 12.5s
# 490:	learn: 1832.4173761	total: 12s	remaining: 12.5s
# 491:	learn: 1832.2329321	total: 12s	remaining: 12.4s
# 492:	learn: 1831.9697885	total: 12s	remaining: 12.4s
# 493:	learn: 1831.4997325	total: 12.1s	remaining: 12.4s
# 494:	learn: 1831.3537455	total: 12.1s	remaining: 12.3s
# 495:	learn: 1831.2133088	total: 12.1s	remaining: 12.3s
# 496:	learn: 1830.8035997	total: 12.1s	remaining: 12.3s
# 497:	learn: 1830.4866932	total: 12.1s	remaining: 12.2s
# 498:	learn: 1830.3562226	total: 12.1s	remaining: 12.2s
# 499:	learn: 1829.6707635	total: 12.2s	remaining: 12.2s
# 500:	learn: 1829.0944759	total: 12.2s	remaining: 12.2s
# 501:	learn: 1828.8227740	total: 12.2s	remaining: 12.1s
# 502:	learn: 1828.4031116	total: 12.2s	remaining: 12.1s
# 503:	learn: 1828.1324345	total: 12.3s	remaining: 12.1s
# 504:	learn: 1827.9427001	total: 12.3s	remaining: 12s
# 505:	learn: 1827.8290302	total: 12.3s	remaining: 12s
# 506:	learn: 1827.5928449	total: 12.3s	remaining: 12s
# 507:	learn: 1827.2787829	total: 12.3s	remaining: 11.9s
# 508:	learn: 1827.0621984	total: 12.3s	remaining: 11.9s
# 509:	learn: 1826.5778058	total: 12.4s	remaining: 11.9s
# 510:	learn: 1826.3650368	total: 12.4s	remaining: 11.9s
# 511:	learn: 1826.2905748	total: 12.4s	remaining: 11.8s
# 512:	learn: 1826.0000288	total: 12.4s	remaining: 11.8s
# 513:	learn: 1825.8266155	total: 12.4s	remaining: 11.8s
# 514:	learn: 1825.6853105	total: 12.5s	remaining: 11.7s
# 515:	learn: 1825.4911119	total: 12.5s	remaining: 11.7s
# 516:	learn: 1825.3874091	total: 12.5s	remaining: 11.7s
# 517:	learn: 1825.1187117	total: 12.5s	remaining: 11.6s
# 518:	learn: 1824.7911148	total: 12.5s	remaining: 11.6s
# 519:	learn: 1824.4891147	total: 12.5s	remaining: 11.6s
# 520:	learn: 1824.3475386	total: 12.6s	remaining: 11.5s
# 521:	learn: 1823.9527379	total: 12.6s	remaining: 11.5s
# 522:	learn: 1823.7775348	total: 12.6s	remaining: 11.5s
# 523:	learn: 1823.5320627	total: 12.6s	remaining: 11.5s
# 524:	learn: 1823.2753656	total: 12.6s	remaining: 11.4s
# 525:	learn: 1823.0320197	total: 12.6s	remaining: 11.4s
# 526:	learn: 1822.6546924	total: 12.7s	remaining: 11.4s
# 527:	learn: 1822.2978247	total: 12.7s	remaining: 11.3s
# 528:	learn: 1821.8991442	total: 12.7s	remaining: 11.3s
# 529:	learn: 1821.7670361	total: 12.7s	remaining: 11.3s
# 530:	learn: 1821.5316733	total: 12.7s	remaining: 11.3s
# 531:	learn: 1821.2759987	total: 12.8s	remaining: 11.2s
# 532:	learn: 1821.0759172	total: 12.8s	remaining: 11.2s
# 533:	learn: 1820.9040320	total: 12.8s	remaining: 11.2s
# 534:	learn: 1820.6711685	total: 12.8s	remaining: 11.1s
# 535:	learn: 1820.5352651	total: 12.8s	remaining: 11.1s
# 536:	learn: 1820.2907608	total: 12.8s	remaining: 11.1s
# 537:	learn: 1820.0646056	total: 12.9s	remaining: 11.1s
# 538:	learn: 1819.8045851	total: 12.9s	remaining: 11s
# 539:	learn: 1819.6271892	total: 12.9s	remaining: 11s
# 540:	learn: 1819.3950713	total: 12.9s	remaining: 11s
# 541:	learn: 1819.2961603	total: 12.9s	remaining: 10.9s
# 542:	learn: 1819.1301222	total: 13s	remaining: 10.9s
# 543:	learn: 1818.6437427	total: 13s	remaining: 10.9s
# 544:	learn: 1818.4786555	total: 13s	remaining: 10.8s
# 545:	learn: 1818.2402697	total: 13s	remaining: 10.8s
# 546:	learn: 1817.9430793	total: 13s	remaining: 10.8s
# 547:	learn: 1817.7800827	total: 13s	remaining: 10.8s
# 548:	learn: 1817.4807492	total: 13.1s	remaining: 10.7s
# 549:	learn: 1817.1848737	total: 13.1s	remaining: 10.7s
# 550:	learn: 1817.0900279	total: 13.1s	remaining: 10.7s
# 551:	learn: 1817.0219121	total: 13.1s	remaining: 10.6s
# 552:	learn: 1816.8460567	total: 13.1s	remaining: 10.6s
# 553:	learn: 1816.7479239	total: 13.1s	remaining: 10.6s
# 554:	learn: 1816.6477423	total: 13.2s	remaining: 10.6s
# 555:	learn: 1816.3835194	total: 13.2s	remaining: 10.5s
# 556:	learn: 1816.1718212	total: 13.2s	remaining: 10.5s
# 557:	learn: 1816.0378343	total: 13.2s	remaining: 10.5s
# 558:	learn: 1815.9023738	total: 13.2s	remaining: 10.4s
# 559:	learn: 1815.5019436	total: 13.3s	remaining: 10.4s
# 560:	learn: 1815.2291527	total: 13.3s	remaining: 10.4s
# 561:	learn: 1814.8378359	total: 13.3s	remaining: 10.4s
# 562:	learn: 1814.6190301	total: 13.3s	remaining: 10.3s
# 563:	learn: 1814.3565406	total: 13.3s	remaining: 10.3s
# 564:	learn: 1814.0533339	total: 13.4s	remaining: 10.3s
# 565:	learn: 1813.6692081	total: 13.4s	remaining: 10.3s
# 566:	learn: 1813.5596465	total: 13.4s	remaining: 10.2s
# 567:	learn: 1813.3674543	total: 13.4s	remaining: 10.2s
# 568:	learn: 1813.1640966	total: 13.4s	remaining: 10.2s
# 569:	learn: 1812.9568718	total: 13.4s	remaining: 10.1s
# 570:	learn: 1812.7441949	total: 13.5s	remaining: 10.1s
# 571:	learn: 1812.5569101	total: 13.5s	remaining: 10.1s
# 572:	learn: 1812.4900735	total: 13.5s	remaining: 10.1s
# 573:	learn: 1812.2843207	total: 13.5s	remaining: 10s
# 574:	learn: 1811.9984832	total: 13.5s	remaining: 10s
# 575:	learn: 1811.8570831	total: 13.5s	remaining: 9.97s
# 576:	learn: 1811.5574049	total: 13.6s	remaining: 9.94s
# 577:	learn: 1811.4148395	total: 13.6s	remaining: 9.91s
# 578:	learn: 1811.1603110	total: 13.6s	remaining: 9.89s
# 579:	learn: 1810.9984172	total: 13.6s	remaining: 9.86s
# 580:	learn: 1810.8015819	total: 13.6s	remaining: 9.83s
# 581:	learn: 1810.4216143	total: 13.6s	remaining: 9.8s
# 582:	learn: 1810.3241240	total: 13.7s	remaining: 9.78s
# 583:	learn: 1810.1603357	total: 13.7s	remaining: 9.75s
# 584:	learn: 1809.9690042	total: 13.7s	remaining: 9.72s
# 585:	learn: 1809.8118141	total: 13.7s	remaining: 9.7s
# 586:	learn: 1809.5510212	total: 13.8s	remaining: 9.68s
# 587:	learn: 1809.3386577	total: 13.8s	remaining: 9.65s
# 588:	learn: 1809.0156894	total: 13.8s	remaining: 9.63s
# 589:	learn: 1808.8365468	total: 13.8s	remaining: 9.6s
# 590:	learn: 1808.6005901	total: 13.8s	remaining: 9.57s
# 591:	learn: 1808.4238946	total: 13.9s	remaining: 9.55s
# 592:	learn: 1808.1424862	total: 13.9s	remaining: 9.53s
# 593:	learn: 1807.9160241	total: 13.9s	remaining: 9.5s
# 594:	learn: 1807.7328238	total: 13.9s	remaining: 9.47s
# 595:	learn: 1807.6140082	total: 13.9s	remaining: 9.45s
# 596:	learn: 1807.4051648	total: 14s	remaining: 9.42s
# 597:	learn: 1807.1443128	total: 14s	remaining: 9.4s
# 598:	learn: 1806.8319086	total: 14s	remaining: 9.38s
# 599:	learn: 1806.5549021	total: 14s	remaining: 9.35s
# 600:	learn: 1806.3360983	total: 14s	remaining: 9.32s
# 601:	learn: 1806.1491771	total: 14.1s	remaining: 9.3s
# 602:	learn: 1805.9095134	total: 14.1s	remaining: 9.28s
# 603:	learn: 1805.5717358	total: 14.1s	remaining: 9.25s
# 604:	learn: 1805.4929035	total: 14.1s	remaining: 9.22s
# 605:	learn: 1805.1763239	total: 14.2s	remaining: 9.2s
# 606:	learn: 1804.8542058	total: 14.2s	remaining: 9.18s
# 607:	learn: 1804.6584920	total: 14.2s	remaining: 9.15s
# 608:	learn: 1804.4653722	total: 14.2s	remaining: 9.14s
# 609:	learn: 1804.4153700	total: 14.2s	remaining: 9.11s
# 610:	learn: 1804.1942787	total: 14.3s	remaining: 9.08s
# 611:	learn: 1803.7536156	total: 14.3s	remaining: 9.06s
# 612:	learn: 1803.5805769	total: 14.3s	remaining: 9.04s
# 613:	learn: 1803.3638439	total: 14.3s	remaining: 9.01s
# 614:	learn: 1803.1799726	total: 14.4s	remaining: 8.98s
# 615:	learn: 1803.0832424	total: 14.4s	remaining: 8.96s
# 616:	learn: 1802.9103409	total: 14.4s	remaining: 8.93s
# 617:	learn: 1802.7659432	total: 14.4s	remaining: 8.9s
# 618:	learn: 1802.4706296	total: 14.4s	remaining: 8.88s
# 619:	learn: 1802.3145055	total: 14.4s	remaining: 8.85s
# 620:	learn: 1802.0687910	total: 14.5s	remaining: 8.83s
# 621:	learn: 1801.8651045	total: 14.5s	remaining: 8.8s
# 622:	learn: 1801.6610320	total: 14.5s	remaining: 8.77s
# 623:	learn: 1801.6104586	total: 14.5s	remaining: 8.75s
# 624:	learn: 1801.2161426	total: 14.5s	remaining: 8.72s
# 625:	learn: 1800.9684066	total: 14.6s	remaining: 8.7s
# 626:	learn: 1800.8221804	total: 14.6s	remaining: 8.67s
# 627:	learn: 1800.4072362	total: 14.6s	remaining: 8.65s
# 628:	learn: 1800.2682795	total: 14.6s	remaining: 8.63s
# 629:	learn: 1800.0896875	total: 14.6s	remaining: 8.6s
# 630:	learn: 1799.9679255	total: 14.7s	remaining: 8.57s
# 631:	learn: 1799.8054099	total: 14.7s	remaining: 8.55s
# 632:	learn: 1799.6162419	total: 14.7s	remaining: 8.52s
# 633:	learn: 1799.4012619	total: 14.7s	remaining: 8.49s
# 634:	learn: 1799.0566351	total: 14.7s	remaining: 8.47s
# 635:	learn: 1798.8950370	total: 14.8s	remaining: 8.45s
# 636:	learn: 1798.6429160	total: 14.8s	remaining: 8.42s
# 637:	learn: 1798.4909937	total: 14.8s	remaining: 8.4s
# 638:	learn: 1798.4046730	total: 14.8s	remaining: 8.37s
# 639:	learn: 1798.1427415	total: 14.8s	remaining: 8.35s
# 640:	learn: 1798.0127135	total: 14.9s	remaining: 8.32s
# 641:	learn: 1797.8979999	total: 14.9s	remaining: 8.29s
# 642:	learn: 1797.7900787	total: 14.9s	remaining: 8.27s
# 643:	learn: 1797.5788728	total: 14.9s	remaining: 8.24s
# 644:	learn: 1797.3187250	total: 14.9s	remaining: 8.21s
# 645:	learn: 1797.1526160	total: 15s	remaining: 8.2s
# 646:	learn: 1796.9220013	total: 15s	remaining: 8.17s
# 647:	learn: 1796.7325994	total: 15s	remaining: 8.15s
# 648:	learn: 1796.5792075	total: 15s	remaining: 8.12s
# 649:	learn: 1796.5052818	total: 15s	remaining: 8.09s
# 650:	learn: 1796.3026676	total: 15.1s	remaining: 8.07s
# 651:	learn: 1796.1112673	total: 15.1s	remaining: 8.04s
# 652:	learn: 1795.9629745	total: 15.1s	remaining: 8.02s
# 653:	learn: 1795.8428673	total: 15.1s	remaining: 7.99s
# 654:	learn: 1795.6362958	total: 15.1s	remaining: 7.97s
# 655:	learn: 1795.5135569	total: 15.1s	remaining: 7.94s
# 656:	learn: 1795.3320112	total: 15.2s	remaining: 7.92s
# 657:	learn: 1795.2111857	total: 15.2s	remaining: 7.9s
# 658:	learn: 1795.0248053	total: 15.2s	remaining: 7.88s
# 659:	learn: 1794.7985002	total: 15.3s	remaining: 7.86s
# 660:	learn: 1794.6939286	total: 15.3s	remaining: 7.83s
# 661:	learn: 1794.4172416	total: 15.3s	remaining: 7.81s
# 662:	learn: 1794.2335118	total: 15.3s	remaining: 7.78s
# 663:	learn: 1794.1156878	total: 15.3s	remaining: 7.76s
# 664:	learn: 1794.0374760	total: 15.4s	remaining: 7.73s
# 665:	learn: 1793.7356376	total: 15.4s	remaining: 7.71s
# 666:	learn: 1793.5055915	total: 15.4s	remaining: 7.69s
# 667:	learn: 1793.3762398	total: 15.4s	remaining: 7.67s
# 668:	learn: 1793.2501040	total: 15.4s	remaining: 7.64s
# 669:	learn: 1793.1051929	total: 15.5s	remaining: 7.62s
# 670:	learn: 1792.8407103	total: 15.5s	remaining: 7.59s
# 671:	learn: 1792.6731893	total: 15.5s	remaining: 7.57s
# 672:	learn: 1792.3944103	total: 15.5s	remaining: 7.54s
# 673:	learn: 1792.2029728	total: 15.5s	remaining: 7.51s
# 674:	learn: 1792.1000435	total: 15.6s	remaining: 7.49s
# 675:	learn: 1791.9190058	total: 15.6s	remaining: 7.46s
# 676:	learn: 1791.7569785	total: 15.6s	remaining: 7.44s
# 677:	learn: 1791.6873201	total: 15.6s	remaining: 7.42s
# 678:	learn: 1791.5246904	total: 15.6s	remaining: 7.39s
# 679:	learn: 1791.3252168	total: 15.7s	remaining: 7.37s
# 680:	learn: 1791.1226197	total: 15.7s	remaining: 7.34s
# 681:	learn: 1791.0016901	total: 15.7s	remaining: 7.32s
# 682:	learn: 1790.8533989	total: 15.7s	remaining: 7.29s
# 683:	learn: 1790.7784217	total: 15.7s	remaining: 7.27s
# 684:	learn: 1790.5916018	total: 15.7s	remaining: 7.24s
# 685:	learn: 1790.4341357	total: 15.8s	remaining: 7.21s
# 686:	learn: 1790.2220640	total: 15.8s	remaining: 7.19s
# 687:	learn: 1790.0662671	total: 15.8s	remaining: 7.16s
# 688:	learn: 1789.8157525	total: 15.8s	remaining: 7.14s
# 689:	learn: 1789.6646505	total: 15.8s	remaining: 7.12s
# 690:	learn: 1789.3380741	total: 15.9s	remaining: 7.09s
# 691:	learn: 1789.2986101	total: 15.9s	remaining: 7.06s
# 692:	learn: 1789.1853372	total: 15.9s	remaining: 7.04s
# 693:	learn: 1789.0879726	total: 15.9s	remaining: 7.01s
# 694:	learn: 1788.7707123	total: 15.9s	remaining: 6.99s
# 695:	learn: 1788.5961544	total: 15.9s	remaining: 6.96s
# 696:	learn: 1788.3972745	total: 16s	remaining: 6.94s
# 697:	learn: 1788.1871781	total: 16s	remaining: 6.91s
# 698:	learn: 1788.0642485	total: 16s	remaining: 6.88s
# 699:	learn: 1787.7779545	total: 16s	remaining: 6.86s
# 700:	learn: 1787.5937992	total: 16s	remaining: 6.83s
# 701:	learn: 1787.3425077	total: 16s	remaining: 6.81s
# 702:	learn: 1787.0997761	total: 16.1s	remaining: 6.79s
# 703:	learn: 1786.9975639	total: 16.1s	remaining: 6.76s
# 704:	learn: 1786.8759384	total: 16.1s	remaining: 6.73s
# 705:	learn: 1786.7388962	total: 16.1s	remaining: 6.71s
# 706:	learn: 1786.6667006	total: 16.1s	remaining: 6.68s
# 707:	learn: 1786.4584750	total: 16.1s	remaining: 6.66s
# 708:	learn: 1786.2161931	total: 16.2s	remaining: 6.63s
# 709:	learn: 1785.9961103	total: 16.2s	remaining: 6.61s
# 710:	learn: 1785.8666883	total: 16.2s	remaining: 6.58s
# 711:	learn: 1785.7419685	total: 16.2s	remaining: 6.56s
# 712:	learn: 1785.4092098	total: 16.3s	remaining: 6.54s
# 713:	learn: 1785.2323453	total: 16.3s	remaining: 6.52s
# 714:	learn: 1785.1955237	total: 16.3s	remaining: 6.5s
# 715:	learn: 1785.0507175	total: 16.3s	remaining: 6.47s
# 716:	learn: 1784.8747229	total: 16.3s	remaining: 6.45s
# 717:	learn: 1784.6984536	total: 16.4s	remaining: 6.42s
# 718:	learn: 1784.4455637	total: 16.4s	remaining: 6.4s
# 719:	learn: 1784.2249444	total: 16.4s	remaining: 6.37s
# 720:	learn: 1784.0462377	total: 16.4s	remaining: 6.35s
# 721:	learn: 1783.8118130	total: 16.4s	remaining: 6.32s
# 722:	learn: 1783.5652706	total: 16.4s	remaining: 6.3s
# 723:	learn: 1783.3266109	total: 16.5s	remaining: 6.27s
# 724:	learn: 1783.1186511	total: 16.5s	remaining: 6.25s
# 725:	learn: 1783.0017582	total: 16.5s	remaining: 6.22s
# 726:	learn: 1782.8852246	total: 16.5s	remaining: 6.2s
# 727:	learn: 1782.6564679	total: 16.5s	remaining: 6.17s
# 728:	learn: 1782.5247553	total: 16.5s	remaining: 6.15s
# 729:	learn: 1782.3364523	total: 16.6s	remaining: 6.12s
# 730:	learn: 1782.2971463	total: 16.6s	remaining: 6.1s
# 731:	learn: 1782.1759399	total: 16.6s	remaining: 6.08s
# 732:	learn: 1782.0783435	total: 16.6s	remaining: 6.05s
# 733:	learn: 1781.9457983	total: 16.6s	remaining: 6.03s
# 734:	learn: 1781.8593829	total: 16.6s	remaining: 6s
# 735:	learn: 1781.7755826	total: 16.7s	remaining: 5.98s
# 736:	learn: 1781.5026670	total: 16.7s	remaining: 5.95s
# 737:	learn: 1781.3224426	total: 16.7s	remaining: 5.93s
# 738:	learn: 1781.1564023	total: 16.7s	remaining: 5.91s
# 739:	learn: 1780.9511840	total: 16.8s	remaining: 5.89s
# 740:	learn: 1780.6452324	total: 16.8s	remaining: 5.87s
# 741:	learn: 1780.3593671	total: 16.8s	remaining: 5.86s
# 742:	learn: 1780.2082122	total: 16.9s	remaining: 5.84s
# 743:	learn: 1779.9136880	total: 16.9s	remaining: 5.82s
# 744:	learn: 1779.7482986	total: 17s	remaining: 5.81s
# 745:	learn: 1779.6490803	total: 17s	remaining: 5.79s
# 746:	learn: 1779.5665384	total: 17s	remaining: 5.77s
# 747:	learn: 1779.3990275	total: 17.1s	remaining: 5.75s
# 748:	learn: 1779.2621759	total: 17.1s	remaining: 5.73s
# 749:	learn: 1779.1491324	total: 17.2s	remaining: 5.72s
# 750:	learn: 1779.0185744	total: 17.2s	remaining: 5.7s
# 751:	learn: 1778.9415364	total: 17.2s	remaining: 5.68s
# 752:	learn: 1778.8730198	total: 17.3s	remaining: 5.66s
# 753:	learn: 1778.8123415	total: 17.3s	remaining: 5.65s
# 754:	learn: 1778.6586258	total: 17.4s	remaining: 5.63s
# 755:	learn: 1778.4860306	total: 17.4s	remaining: 5.61s
# 756:	learn: 1778.3077014	total: 17.4s	remaining: 5.59s
# 757:	learn: 1778.2717426	total: 17.5s	remaining: 5.57s
# 758:	learn: 1778.1500083	total: 17.5s	remaining: 5.56s
# 759:	learn: 1777.9879970	total: 17.6s	remaining: 5.54s
# 760:	learn: 1777.7895697	total: 17.6s	remaining: 5.53s
# 761:	learn: 1777.5766920	total: 17.7s	remaining: 5.52s
# 762:	learn: 1777.5071152	total: 17.7s	remaining: 5.5s
# 763:	learn: 1777.3113491	total: 17.8s	remaining: 5.48s
# 764:	learn: 1777.1318441	total: 17.8s	remaining: 5.47s
# 765:	learn: 1777.0379583	total: 17.8s	remaining: 5.45s
# 766:	learn: 1776.9257715	total: 17.9s	remaining: 5.44s
# 767:	learn: 1776.7515336	total: 17.9s	remaining: 5.42s
# 768:	learn: 1776.5705609	total: 18s	remaining: 5.41s
# 769:	learn: 1776.5107334	total: 18s	remaining: 5.39s
# 770:	learn: 1776.3166263	total: 18.1s	remaining: 5.37s
# 771:	learn: 1776.1994208	total: 18.1s	remaining: 5.35s
# 772:	learn: 1776.0347326	total: 18.2s	remaining: 5.34s
# 773:	learn: 1775.9463182	total: 18.2s	remaining: 5.32s
# 774:	learn: 1775.6791351	total: 18.3s	remaining: 5.31s
# 775:	learn: 1775.4527921	total: 18.3s	remaining: 5.29s
# 776:	learn: 1775.3728273	total: 18.4s	remaining: 5.27s
# 777:	learn: 1775.1964839	total: 18.4s	remaining: 5.25s
# 778:	learn: 1775.1473769	total: 18.5s	remaining: 5.23s
# 779:	learn: 1774.8504824	total: 18.5s	remaining: 5.22s
# 780:	learn: 1774.3916260	total: 18.6s	remaining: 5.2s
# 781:	learn: 1774.3094733	total: 18.6s	remaining: 5.18s
# 782:	learn: 1774.1013093	total: 18.6s	remaining: 5.16s
# 783:	learn: 1773.9748988	total: 18.7s	remaining: 5.14s
# 784:	learn: 1773.8799980	total: 18.7s	remaining: 5.12s
# 785:	learn: 1773.7513468	total: 18.7s	remaining: 5.09s
# 786:	learn: 1773.5636995	total: 18.7s	remaining: 5.07s
# 787:	learn: 1773.2804462	total: 18.8s	remaining: 5.06s
# 788:	learn: 1773.2466604	total: 18.8s	remaining: 5.03s
# 789:	learn: 1773.1026844	total: 18.8s	remaining: 5.01s
# 790:	learn: 1772.9156920	total: 18.9s	remaining: 4.99s
# 791:	learn: 1772.6980058	total: 18.9s	remaining: 4.97s
# 792:	learn: 1772.5717246	total: 18.9s	remaining: 4.95s
# 793:	learn: 1772.4560769	total: 19s	remaining: 4.92s
# 794:	learn: 1772.3749000	total: 19s	remaining: 4.9s
# 795:	learn: 1772.2345573	total: 19s	remaining: 4.88s
# 796:	learn: 1772.0263043	total: 19.1s	remaining: 4.86s
# 797:	learn: 1771.7955472	total: 19.1s	remaining: 4.85s
# 798:	learn: 1771.6875182	total: 19.2s	remaining: 4.83s
# 799:	learn: 1771.4730276	total: 19.2s	remaining: 4.81s
# 800:	learn: 1771.3740888	total: 19.3s	remaining: 4.79s
# 801:	learn: 1771.1966400	total: 19.3s	remaining: 4.77s
# 802:	learn: 1771.0483096	total: 19.4s	remaining: 4.76s
# 803:	learn: 1770.8875794	total: 19.5s	remaining: 4.74s
# 804:	learn: 1770.6347528	total: 19.5s	remaining: 4.72s
# 805:	learn: 1770.5106309	total: 19.5s	remaining: 4.71s
# 806:	learn: 1770.3860921	total: 19.6s	remaining: 4.69s
# 807:	learn: 1770.2747616	total: 19.7s	remaining: 4.67s
# 808:	learn: 1770.0936454	total: 19.7s	remaining: 4.65s
# 809:	learn: 1769.9147826	total: 19.8s	remaining: 4.64s
# 810:	learn: 1769.7853503	total: 19.8s	remaining: 4.61s
# 811:	learn: 1769.5696168	total: 19.9s	remaining: 4.6s
# 812:	learn: 1769.3666774	total: 19.9s	remaining: 4.58s
# 813:	learn: 1769.0710647	total: 19.9s	remaining: 4.56s
# 814:	learn: 1768.8695290	total: 20s	remaining: 4.54s
# 815:	learn: 1768.7365634	total: 20s	remaining: 4.52s
# 816:	learn: 1768.5125190	total: 20.1s	remaining: 4.5s
# 817:	learn: 1768.3764820	total: 20.1s	remaining: 4.48s
# 818:	learn: 1768.2049119	total: 20.2s	remaining: 4.46s
# 819:	learn: 1767.9487110	total: 20.2s	remaining: 4.44s
# 820:	learn: 1767.7499157	total: 20.3s	remaining: 4.42s
# 821:	learn: 1767.5165884	total: 20.3s	remaining: 4.4s
# 822:	learn: 1767.3891724	total: 20.4s	remaining: 4.38s
# 823:	learn: 1767.2681339	total: 20.4s	remaining: 4.36s
# 824:	learn: 1767.2272402	total: 20.4s	remaining: 4.34s
# 825:	learn: 1767.1200889	total: 20.5s	remaining: 4.31s
# 826:	learn: 1767.0621038	total: 20.5s	remaining: 4.3s
# 827:	learn: 1766.9073585	total: 20.6s	remaining: 4.28s
# 828:	learn: 1766.7140017	total: 20.7s	remaining: 4.26s
# 829:	learn: 1766.5242828	total: 20.7s	remaining: 4.24s
# 830:	learn: 1766.1765930	total: 20.7s	remaining: 4.22s
# 831:	learn: 1766.0033152	total: 20.8s	remaining: 4.2s
# 832:	learn: 1765.9476262	total: 20.8s	remaining: 4.17s
# 833:	learn: 1765.7877932	total: 20.9s	remaining: 4.15s
# 834:	learn: 1765.6793269	total: 20.9s	remaining: 4.13s
# 835:	learn: 1765.4861608	total: 20.9s	remaining: 4.1s
# 836:	learn: 1765.3760726	total: 20.9s	remaining: 4.07s
# 837:	learn: 1765.1774041	total: 20.9s	remaining: 4.05s
# 838:	learn: 1764.9949845	total: 21s	remaining: 4.02s
# 839:	learn: 1764.8359891	total: 21s	remaining: 4s
# 840:	learn: 1764.6501612	total: 21s	remaining: 3.97s
# 841:	learn: 1764.3572145	total: 21s	remaining: 3.94s
# 842:	learn: 1764.2232953	total: 21s	remaining: 3.92s
# 843:	learn: 1763.9765127	total: 21.1s	remaining: 3.89s
# 844:	learn: 1763.8276969	total: 21.1s	remaining: 3.87s
# 845:	learn: 1763.7379243	total: 21.1s	remaining: 3.84s
# 846:	learn: 1763.6145038	total: 21.1s	remaining: 3.81s
# 847:	learn: 1763.5508417	total: 21.1s	remaining: 3.79s
# 848:	learn: 1763.4362741	total: 21.1s	remaining: 3.76s
# 849:	learn: 1763.2734761	total: 21.2s	remaining: 3.73s
# 850:	learn: 1763.2077216	total: 21.2s	remaining: 3.71s
# 851:	learn: 1763.0103476	total: 21.2s	remaining: 3.68s
# 852:	learn: 1762.9073620	total: 21.2s	remaining: 3.65s
# 853:	learn: 1762.6428192	total: 21.2s	remaining: 3.63s
# 854:	learn: 1762.6125615	total: 21.2s	remaining: 3.6s
# 855:	learn: 1762.4957905	total: 21.3s	remaining: 3.58s
# 856:	learn: 1762.3392933	total: 21.3s	remaining: 3.55s
# 857:	learn: 1762.2200574	total: 21.3s	remaining: 3.52s
# 858:	learn: 1762.1374074	total: 21.3s	remaining: 3.5s
# 859:	learn: 1762.0224897	total: 21.3s	remaining: 3.47s
# 860:	learn: 1761.9078487	total: 21.3s	remaining: 3.45s
# 861:	learn: 1761.6721794	total: 21.4s	remaining: 3.42s
# 862:	learn: 1761.4969483	total: 21.4s	remaining: 3.4s
# 863:	learn: 1761.4498005	total: 21.4s	remaining: 3.37s
# 864:	learn: 1761.3176659	total: 21.4s	remaining: 3.35s
# 865:	learn: 1761.1107010	total: 21.5s	remaining: 3.32s
# 866:	learn: 1760.9293177	total: 21.5s	remaining: 3.29s
# 867:	learn: 1760.7193466	total: 21.5s	remaining: 3.27s
# 868:	learn: 1760.6335834	total: 21.5s	remaining: 3.24s
# 869:	learn: 1760.5818127	total: 21.5s	remaining: 3.22s
# 870:	learn: 1760.4146637	total: 21.5s	remaining: 3.19s
# 871:	learn: 1760.2674587	total: 21.6s	remaining: 3.16s
# 872:	learn: 1760.0299995	total: 21.6s	remaining: 3.14s
# 873:	learn: 1759.8507378	total: 21.6s	remaining: 3.12s
# 874:	learn: 1759.7336761	total: 21.6s	remaining: 3.09s
# 875:	learn: 1759.6498825	total: 21.6s	remaining: 3.06s
# 876:	learn: 1759.5388679	total: 21.7s	remaining: 3.04s
# 877:	learn: 1759.4419344	total: 21.7s	remaining: 3.01s
# 878:	learn: 1759.2796280	total: 21.7s	remaining: 2.99s
# 879:	learn: 1759.1282801	total: 21.7s	remaining: 2.96s
# 880:	learn: 1759.0090233	total: 21.7s	remaining: 2.94s
# 881:	learn: 1758.8837387	total: 21.8s	remaining: 2.91s
# 882:	learn: 1758.7065234	total: 21.8s	remaining: 2.88s
# 883:	learn: 1758.6403592	total: 21.8s	remaining: 2.86s
# 884:	learn: 1758.4385803	total: 21.8s	remaining: 2.84s
# 885:	learn: 1758.3427928	total: 21.8s	remaining: 2.81s
# 886:	learn: 1758.2336086	total: 21.9s	remaining: 2.79s
# 887:	learn: 1758.1309737	total: 21.9s	remaining: 2.76s
# 888:	learn: 1757.9691806	total: 21.9s	remaining: 2.73s
# 889:	learn: 1757.9228570	total: 21.9s	remaining: 2.71s
# 890:	learn: 1757.7678169	total: 21.9s	remaining: 2.68s
# 891:	learn: 1757.6027839	total: 22s	remaining: 2.66s
# 892:	learn: 1757.4633785	total: 22s	remaining: 2.63s
# 893:	learn: 1757.3943837	total: 22s	remaining: 2.61s
# 894:	learn: 1757.3144273	total: 22s	remaining: 2.58s
# 895:	learn: 1757.0856591	total: 22s	remaining: 2.56s
# 896:	learn: 1756.8312132	total: 22.1s	remaining: 2.53s
# 897:	learn: 1756.6426860	total: 22.1s	remaining: 2.51s
# 898:	learn: 1756.5297606	total: 22.1s	remaining: 2.48s
# 899:	learn: 1756.2348463	total: 22.1s	remaining: 2.46s
# 900:	learn: 1756.0288928	total: 22.1s	remaining: 2.43s
# 901:	learn: 1755.8418326	total: 22.2s	remaining: 2.41s
# 902:	learn: 1755.5928371	total: 22.2s	remaining: 2.38s
# 903:	learn: 1755.4120847	total: 22.2s	remaining: 2.36s
# 904:	learn: 1755.2835806	total: 22.2s	remaining: 2.33s
# 905:	learn: 1755.2707240	total: 22.2s	remaining: 2.31s
# 906:	learn: 1754.9295017	total: 22.3s	remaining: 2.28s
# 907:	learn: 1754.8154944	total: 22.3s	remaining: 2.26s
# 908:	learn: 1754.7385288	total: 22.3s	remaining: 2.23s
# 909:	learn: 1754.6191906	total: 22.3s	remaining: 2.21s
# 910:	learn: 1754.5231429	total: 22.3s	remaining: 2.18s
# 911:	learn: 1754.4772824	total: 22.4s	remaining: 2.16s
# 912:	learn: 1754.3603537	total: 22.4s	remaining: 2.13s
# 913:	learn: 1754.1829196	total: 22.4s	remaining: 2.11s
# 914:	learn: 1754.0369000	total: 22.4s	remaining: 2.08s
# 915:	learn: 1753.7647465	total: 22.5s	remaining: 2.06s
# 916:	learn: 1753.6689352	total: 22.5s	remaining: 2.04s
# 917:	learn: 1753.5488445	total: 22.5s	remaining: 2.01s
# 918:	learn: 1753.3592098	total: 22.5s	remaining: 1.99s
# 919:	learn: 1753.2492463	total: 22.6s	remaining: 1.96s
# 920:	learn: 1753.0957707	total: 22.6s	remaining: 1.94s
# 921:	learn: 1752.8757913	total: 22.6s	remaining: 1.91s
# 922:	learn: 1752.7375816	total: 22.6s	remaining: 1.89s
# 923:	learn: 1752.5854723	total: 22.6s	remaining: 1.86s
# 924:	learn: 1752.4977310	total: 22.7s	remaining: 1.84s
# 925:	learn: 1752.3424916	total: 22.7s	remaining: 1.81s
# 926:	learn: 1752.1888301	total: 22.7s	remaining: 1.79s
# 927:	learn: 1752.0654191	total: 22.7s	remaining: 1.76s
# 928:	learn: 1752.0003344	total: 22.7s	remaining: 1.74s
# 929:	learn: 1751.8959212	total: 22.8s	remaining: 1.71s
# 930:	learn: 1751.7959597	total: 22.8s	remaining: 1.69s
# 931:	learn: 1751.6222838	total: 22.8s	remaining: 1.66s
# 932:	learn: 1751.4724108	total: 22.8s	remaining: 1.64s
# 933:	learn: 1751.3152945	total: 22.8s	remaining: 1.61s
# 934:	learn: 1751.1046723	total: 22.8s	remaining: 1.59s
# 935:	learn: 1751.0040917	total: 22.9s	remaining: 1.56s
# 936:	learn: 1750.8855961	total: 22.9s	remaining: 1.54s
# 937:	learn: 1750.7109930	total: 22.9s	remaining: 1.51s
# 938:	learn: 1750.5626398	total: 22.9s	remaining: 1.49s
# 939:	learn: 1750.4328613	total: 22.9s	remaining: 1.46s
# 940:	learn: 1750.2556914	total: 22.9s	remaining: 1.44s
# 941:	learn: 1750.1044219	total: 23s	remaining: 1.41s
# 942:	learn: 1749.9066554	total: 23s	remaining: 1.39s
# 943:	learn: 1749.8317488	total: 23s	remaining: 1.36s
# 944:	learn: 1749.6733289	total: 23s	remaining: 1.34s
# 945:	learn: 1749.3788131	total: 23s	remaining: 1.31s
# 946:	learn: 1749.2206381	total: 23.1s	remaining: 1.29s
# 947:	learn: 1749.1633087	total: 23.1s	remaining: 1.26s
# 948:	learn: 1749.0828356	total: 23.1s	remaining: 1.24s
# 949:	learn: 1748.8882695	total: 23.1s	remaining: 1.22s
# 950:	learn: 1748.6857314	total: 23.1s	remaining: 1.19s
# 951:	learn: 1748.5927486	total: 23.1s	remaining: 1.17s
# 952:	learn: 1748.4405600	total: 23.2s	remaining: 1.14s
# 953:	learn: 1748.3232804	total: 23.2s	remaining: 1.12s
# 954:	learn: 1748.2523277	total: 23.2s	remaining: 1.09s
# 955:	learn: 1748.0628337	total: 23.2s	remaining: 1.07s
# 956:	learn: 1747.9812988	total: 23.2s	remaining: 1.04s
# 957:	learn: 1747.8008548	total: 23.3s	remaining: 1.02s
# 958:	learn: 1747.5752955	total: 23.3s	remaining: 996ms
# 959:	learn: 1747.4565672	total: 23.3s	remaining: 971ms
# 960:	learn: 1747.3819964	total: 23.3s	remaining: 946ms
# 961:	learn: 1747.2275577	total: 23.3s	remaining: 922ms
# 962:	learn: 1747.1711511	total: 23.4s	remaining: 898ms
# 963:	learn: 1747.0107334	total: 23.4s	remaining: 873ms
# 964:	learn: 1746.8713135	total: 23.4s	remaining: 848ms
# 965:	learn: 1746.8010664	total: 23.4s	remaining: 824ms
# 966:	learn: 1746.7587996	total: 23.4s	remaining: 799ms
# 967:	learn: 1746.6113392	total: 23.5s	remaining: 775ms
# 968:	learn: 1746.5112755	total: 23.5s	remaining: 751ms
# 969:	learn: 1746.4431100	total: 23.5s	remaining: 727ms
# 970:	learn: 1746.3182810	total: 23.5s	remaining: 702ms
# 971:	learn: 1746.1509814	total: 23.5s	remaining: 678ms
# 972:	learn: 1745.8374352	total: 23.6s	remaining: 654ms
# 973:	learn: 1745.6585335	total: 23.6s	remaining: 629ms
# 974:	learn: 1745.5249220	total: 23.6s	remaining: 605ms
# 975:	learn: 1745.4109696	total: 23.6s	remaining: 581ms
# 976:	learn: 1745.2641202	total: 23.6s	remaining: 556ms
# 977:	learn: 1745.1386779	total: 23.6s	remaining: 532ms
# 978:	learn: 1745.0605221	total: 23.7s	remaining: 508ms
# 979:	learn: 1744.9742535	total: 23.7s	remaining: 483ms
# 980:	learn: 1744.8823018	total: 23.7s	remaining: 459ms
# 981:	learn: 1744.7633141	total: 23.7s	remaining: 435ms
# 982:	learn: 1744.5864104	total: 23.7s	remaining: 410ms
# 983:	learn: 1744.4518435	total: 23.8s	remaining: 386ms
# 984:	learn: 1744.3421264	total: 23.8s	remaining: 362ms
# 985:	learn: 1744.3138548	total: 23.8s	remaining: 338ms
# 986:	learn: 1744.1328957	total: 23.8s	remaining: 314ms
# 987:	learn: 1744.0370867	total: 23.8s	remaining: 289ms
# 988:	learn: 1743.9160615	total: 23.8s	remaining: 265ms
# 989:	learn: 1743.8879832	total: 23.9s	remaining: 241ms
# 990:	learn: 1743.7376785	total: 23.9s	remaining: 217ms
# 991:	learn: 1743.6147999	total: 23.9s	remaining: 193ms
# 992:	learn: 1743.3260005	total: 23.9s	remaining: 169ms
# 993:	learn: 1743.2721499	total: 23.9s	remaining: 144ms
# 994:	learn: 1743.1432587	total: 23.9s	remaining: 120ms
# 995:	learn: 1743.0343487	total: 24s	remaining: 96.2ms
# 996:	learn: 1742.9603222	total: 24s	remaining: 72.2ms
# 997:	learn: 1742.8862678	total: 24s	remaining: 48.1ms
# 998:	learn: 1742.8226791	total: 24s	remaining: 24ms
# 999:	learn: 1742.7028624	total: 24s	remaining: 0us
# CPU times: user 38.1 s, sys: 1.67 s, total: 39.8 s
# Wall time: 25.5 s

# %%
# %%time

pred_train = model.predict(features_train)
pred_valid = model.predict(features_valid)
pred_test = model.predict(features_test)

print("Train RSME:", rmse(target_train, pred_train).round(5))
print("Valid RSME:", rmse(target_valid, pred_valid).round(5))
print("Test RSME:", rmse(target_test, pred_test).round(5))
# Out:
# Train RSME: 1742.70286
# Valid RSME: 1815.35414
# Test RSME: 1806.62819
# CPU times: user 1.31 s, sys: 22.9 ms, total: 1.33 s
# Wall time: 722 ms

# %% [markdown]
# **CatBoost**
#
# Training Time
#
# The CatBoost model was trained with default hyperparameters. The training process took approximately 39.8 seconds, indicating significant computational requirements compared to other models.
#
# Prediction Speed
#
# Despite the longer training time, the prediction phase for the CatBoost model was relatively fast, with predictions for all datasets (train, validation, and test) completed in approximately 1.33 seconds. This demonstrates efficient prediction speed once the model is trained.
#
# Prediction Quality
#
# The performance metrics for the CatBoost model on different datasets are as follows:
#   * Train RSME: 1742.70286
#   * Valid RSME: 1815.35414
#   * Test RSME: 1806.62819
#
# The Root Mean Squared Error (RSME) values indicate the average deviation of predicted car prices from actual prices. The CatBoost model demonstrates competitive predictive accuracy on all datasets, with relatively low RSME values.
#
# **Conclusion**
#
# Despite the longer training time, the CatBoost model showcases impressive predictive accuracy and efficient prediction speed. With its inherent ability to handle categorical features and robust performance, CatBoost emerges as a powerful tool for estimating the market value of used cars accurately. However, considerations should be made regarding computational resources when deploying CatBoost in real-world applications. Overall, the CatBoost model offers a promising solution for Rusty Bargain's goal of developing a reliable application for estimating car market values.

# %% [markdown]
# # Conclusion and Model Selection

# %% [markdown]
# ## Based on the analysis of prediction quality, speed, and training time, select the best-performing model(s) for deployment in Rusty Bargain's application.

# %% [markdown]
# After analyzing the performance of various machine learning models for predicting car market values, let's summarize our findings and decide on the best-performing model for deployment in Rusty Bargain's application.
#
# **Linear Regression**
#   * Training Time: Moderate (12.5 seconds)
#   * Prediction Speed: Fast (1.44 seconds)
#   * Prediction Quality: Moderate (RSME values suggest room for improvement)
#
# **Decision Tree**
#   * Training Time: Moderate (4.26 seconds)
#   * Prediction Speed: Fast (509 milliseconds)
#   * Prediction Quality: Reasonably good (RSME values indicate improvement over linear regression)
#
# **Random Forest**
#   * Training Time: Significant (3 minutes and 13 seconds)
#   * Prediction Speed: Fast (2.67 seconds)
#   * Prediction Quality: Good (Balanced RSME values with improved performance over decision tree)
#
# **LightGBM (Gradient Boosting)**
#   * Training Time: Fast (1.86 seconds)
#   * Prediction Speed: Very fast (1.06 seconds)
#   * Prediction Quality: Competitive (Low RSME values, indicating good accuracy)
#
# **CatBoost**
#   * Training Time: Significant (39.8 seconds)
#   * Prediction Speed: Fast (1.33 seconds)
#   * Prediction Quality: Competitive (Low RSME values, indicating good accuracy)
#
# **Conclusion**
#
# Based on the analysis of prediction quality, speed, and training time, the best-performing models for deployment in Rusty Bargain's application are:
#
# 1. CatBoost: Despite having a longer training time compared to other models, CatBoost demonstrates impressive predictive accuracy and efficient prediction speed. With competitive RSME values across all datasets and the ability to handle categorical features effectively, CatBoost emerges as a powerful tool for estimating the market value of used cars accurately.
#
# 2. LightGBM (Gradient Boosting): LightGBM exhibits remarkable performance in terms of training time, prediction speed, and prediction quality. With its efficient handling of gradient boosting and low computational requirements, LightGBM is a promising candidate for accurate and efficient estimation of car market values.
#
# These models offer a balance between predictive accuracy, computational efficiency, and speed, making them suitable choices for deployment in Rusty Bargain's application. Further fine-tuning and optimization may enhance their performance, but their current performance already meets the requirements for reliable estimation of used car prices.
#
# **Next Steps**
#   * Deployment: Deploy the CatBoost model into Rusty Bargain's application for estimating car market values.
#   * Monitoring and Evaluation: Continuously monitor the performance of the deployed model in real-world scenarios and evaluate its accuracy and efficiency.
#   * Feedback Loop: Gather feedback from users and stakeholders regarding the model's performance and usability to identify areas for improvement.
#   * Model Updates: Periodically update the model based on new data, insights, or advancements in machine learning techniques to ensure its continued relevance and accuracy.
#
# Further Research: Explore advanced techniques, such as ensemble methods or neural networks, to potentially improve prediction quality further. Additionally, investigate ways to optimize computational resources and reduce training times without compromising accuracy.

# %% [markdown]
# ## Trade-offs between Models:
#
# 1.	Linear Regression:
#   * Advantages: Simple, fast prediction speed.
#   * Disadvantages: Limited predictive power, assumption of linear relationship may not hold.
# 2.	Decision Tree:
#   * Advantages: Non-linear relationships, interpretable.
#   * Disadvantages: Prone to overfitting, moderate prediction quality.
# 3.	Random Forest:
#   * Advantages: Ensemble of decision trees, reduced overfitting.
#   * Disadvantages: Longer training time, complexity.
# 4.	LightGBM:
#   * Advantages: Efficient handling of gradient boosting, fast prediction speed.
#   * Disadvantages: Moderate training time, potential complexity.
# 5.	CatBoost:
#   * Advantages: Handles categorical features well, robust performance, competitive prediction quality.
#   * Disadvantages: Longer training time compared to some models.
#
# Justification for Choosing CatBoost:
# 1.	Prediction Quality: CatBoost demonstrates competitive prediction quality with lower RMSE values compared to linear regression, decision tree, and random forest. This indicates its effectiveness in accurately estimating car market values.
# 2.	Prediction Speed: Despite longer training time, CatBoost exhibits fast prediction speed, completing predictions for all datasets in a reasonable time frame. This ensures efficient performance during real-time use.
# 3.	Robust Performance: CatBoost's ability to handle categorical features makes it suitable for Rusty Bargain's dataset, which likely contains such features. Its robust performance, evidenced by low RMSE values, ensures reliable predictions even in the presence of categorical variables.
# 4.	Balanced Trade-offs: While CatBoost may have a longer training time compared to some models like linear regression or decision trees, its superior prediction quality justifies the trade-off. The slightly longer training time is acceptable considering the significant improvement in prediction accuracy.
# 5.	Real-world Applicability: Considering Rusty Bargain's need for accurate estimations of car market values, the robust performance and competitive prediction quality of CatBoost make it the optimal choice for deployment in their application.
#
# In summary, the trade-offs between different models were carefully evaluated, and CatBoost emerged as the best-performing model due to its competitive prediction quality, efficient prediction speed, robust performance, and suitability for Rusty Bargain's dataset. The slight increase in training time is justified by the significant improvement in prediction accuracy, making CatBoost the optimal choice for deployment in Rusty Bargain's application.

# %% [markdown]
# # Future Directions

# %% [markdown]
# ## Potential Improvements for the Model:
#
# 1.	Incorporating More Diverse Data Sources:
#   * Obtain additional data sources such as car market trends, economic indicators, or customer preferences to enhance model performance.
#   * Include data from social media or online forums to capture sentiment and consumer behavior towards certain car models or brands.
# 2.	Implementing Advanced Feature Engineering Techniques:
#   * Explore more sophisticated feature engineering methods such as polynomial features, interaction terms, or embeddings to capture complex relationships between features.
#   * Use domain knowledge to create new features that may have a significant impact on car prices, such as vehicle history, maintenance records, or geographic location.
# 3.	Exploring Newer Machine Learning Algorithms:
#   * Investigate newer algorithms such as XGBoost, AutoML, or deep learning models to further improve prediction accuracy and handle more complex patterns in the data.
#   * Experiment with ensemble methods or model stacking techniques to combine the strengths of multiple models and mitigate individual model weaknesses.

# %% [markdown]
# ## Infrastructure and Computational Resources:
#
# 1.	Scalability:
#   * Ensure the deployment infrastructure can handle increased data volume and user traffic over time.
#   * Implement scalable cloud-based solutions such as AWS or Google Cloud Platform to accommodate growing computational demands.
# 2.	Maintainability:
#   * Develop robust monitoring and logging systems to track model performance, data drift, and potential issues in real-time.
#   * Establish regular maintenance schedules for model updates, retraining, and validation to ensure continued accuracy and relevance.
# 3.	Computational Resources:
#   * Allocate sufficient computational resources for training and inference, considering the complexity of the model and the size of the dataset.
#   * Optimize model training pipelines and hyperparameter tuning processes to minimize computational costs while maximizing performance.
# 4.	Model Versioning and Deployment:
#   * Implement version control for models to track changes, rollback to previous versions if necessary, and ensure reproducibility.
#   * Utilize containerization technologies such as Docker for seamless deployment across different environments and platforms.
# 5.	Data Privacy and Security:
#   * Implement robust security measures to protect sensitive user data and ensure compliance with privacy regulations such as GDPR or CCPA.
#   * Implement data anonymization techniques where necessary to protect user privacy while maintaining model performance.
#
# By incorporating these potential improvements and carefully considering infrastructure and computational resources, the model can remain scalable, maintainable, and effective in a production environment, ensuring accurate estimations of car market values for Rusty Bargain's application.
